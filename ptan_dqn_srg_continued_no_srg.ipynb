# %%
# Training DQN using PTAN library

import warnings
warnings.filterwarnings('ignore',category=FutureWarning) 
# suppress numpy future warnings 
# warning created due to issues with tensorflow 1.14


import gym
import ptan
import argparse

import torch
import torch.optim as optim

from torch.utils.tensorboard import SummaryWriter

from lib import dqn_model, common


import os
import random
import numpy as np

# %%
# parser = argparse.ArgumentParser()
# parser.add_argument("--cuda", default=False, action="store_true", help="Enable GPU [default:False]")
# parser.add_argument("--seed", type=int, help="Set seed [default: 42]")
# parser.add_argument("experiment", help="Experiment to run. Specified in ./lib/common.py")



# args = parser.parse_args()

# %%
# set device
USE_GPU = True#args.cuda
USE_CUDA = torch.cuda.is_available() and USE_GPU
device = torch.device("cuda:0" if USE_CUDA else "cpu")
print("DEVICE #", device, ": ", torch.cuda.get_device_name(device))

# %%
# set seed
seed = 953419#args.seed if args.seed else 42
random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

experiment = "beamrider-v1"#args.experiment
params = common.HYPERPARAMS[experiment]

# %%
env = gym.make(params['env_name'])
env = ptan.common.wrappers.wrap_dqn(env)

tag = params['run_name'] + "-basic-srg" + '-'+ str(seed)
writer = SummaryWriter(comment="-"+ tag)

# %%
net = dqn_model.DQN_A(env.observation_space.shape, 
                    env.action_space.n).to(device)

tgt_net = ptan.agent.TargetNet(net)

# %%
selector = ptan.actions.EpsilonGreedyActionSelector(epsilon=params['epsilon_start'])
epsilon_tracker = common.EpsilonTracker(selector, params)
# epsilon_tracker has only one method frame(frame_idx) which changes the epsilon value 
# of selector=>ptan.actions.EpsilonGreedyActionSelector depending upon the frame

# %%
class DQNAgent_srg(ptan.agent.BaseAgent):
    """
    DQNAgent is a memoryless DQN agent which calculates Q values
    from the observations and  converts them into the actions using action_selector
    """
    def __init__(self, dqn_model, action_selector, device="cpu", preprocessor=ptan.agent.default_states_preprocessor):
        self.dqn_model = dqn_model
        self.action_selector = action_selector
        self.preprocessor = preprocessor
        self.device = device

    @torch.no_grad()
    def __call__(self, states, agent_states=None):
        if agent_states is None:
            agent_states = [None] * len(states)
        if self.preprocessor is not None:
            states = self.preprocessor(states)
            if torch.is_tensor(states):
                states = states.to(self.device)
        q_v, _ = self.dqn_model(states)
        q = q_v.data.cpu().numpy()
        actions = self.action_selector(q)
        return actions, agent_states

# %%
agent = DQNAgent_srg(net, selector, device=device)

exp_source = ptan.experience.ExperienceSourceFirstLast(env, agent, gamma=params['gamma'], steps_count=1)

buffer = ptan.experience.ExperienceReplayBuffer(exp_source, buffer_size=params['replay_size'])

optimizer = optim.Adam(net.parameters(), lr=params['learning_rate'])

# %%
frame_idx = 3E6
INTERRPUTED_MODEL_FILENAME = './models/beamrider-v0-basic-srg-953419.pt'
net.load_state_dict(torch.load(INTERRPUTED_MODEL_FILENAME))
tgt_net.sync()

# %%
with common.RewardTracker(writer, params['stop_reward']) as reward_tracker: #create a reward tracker object
    while True:
        frame_idx += 1
        # ExperienceReplayBuffer asks the ExperienceSourceFirstLast to iterate by one step to get the next transition
        # ExperienceSourceFirstLast feeds observation to obtain action
        # Agent calculated Q-values through the NN
        # Action selector selects action
        # Action is fed into ExperienceSource to obtain reward and next obs
        # Buffer stores transition in FIFO order
        buffer.populate(1) # iterates ExperienceReplayBuffer by 1 step.
                            # this in turn iterates exp_source [ExperienceSourceFirstLast] by one step
                            # one single experience step
                            # Experience = namedtuple('Experience', ['state', 'action', 'reward', 'done'])
                            
                            # Class ExperienceSource provides us full subtrajectories of given length as the list of (s, a, r, s') objects.
                            # Now it returns single object on every iteration, which is again a namedtuple with the following fields:

                            # state: state which we used to decide on action to make TYPE: numpy
                            # action: action we've done at this step
                            # reward: partial accumulated reward for steps_count (in our case, steps_count=1, so it is equal to immediate reward)
                            # last_state: the state we've got after executing the action. If our episode ends, we have None here

                            # For every trajectory piece it calculates discounted reward and emits only first and last states and action taken in the first state.
        epsilon_tracker.frame(frame_idx)
        

        new_rewards = exp_source.pop_total_rewards() # get rewards from the episodes
        if new_rewards:
            if reward_tracker.reward(new_rewards[0], frame_idx, selector.epsilon):
                break

        if len(buffer) < params['replay_initial']:
            continue

        optimizer.zero_grad()
        batch = buffer.sample(params['batch_size'])
        loss_v, feature_loss, qvalue_loss = common.calc_loss_srg_disabled(batch, net, tgt_net.target_model, gamma=params['gamma'], device=device)
        if frame_idx % 1E3 == 0:
            writer.add_scalar("loss", loss_v, frame_idx)
            writer.add_scalar("feature_loss", feature_loss, frame_idx)
            writer.add_scalar("qvalue_loss", qvalue_loss, frame_idx)
        loss_v.backward()
        optimizer.step()

        if frame_idx % params['target_net_sync'] == 0:
            tgt_net.sync()
            
        if frame_idx > 6E6:
            break
# Out:
# 3000521: done 1 games, mean reward 7.000, speed 2973721.16 f/s, eps 0.10
# 3001006: done 2 games, mean reward 7.500, speed 654.95 f/s, eps 0.10
# 3002010: done 3 games, mean reward 10.000, speed 609.43 f/s, eps 0.10
# 3002539: done 4 games, mean reward 9.000, speed 606.56 f/s, eps 0.10
# 3003003: done 5 games, mean reward 8.600, speed 528.99 f/s, eps 0.10
# 3004211: done 6 games, mean reward 9.667, speed 565.44 f/s, eps 0.10
# 3007098: done 7 games, mean reward 13.571, speed 528.23 f/s, eps 0.10
# 3009229: done 8 games, mean reward 16.750, speed 597.53 f/s, eps 0.10
# 3009538: done 9 games, mean reward 15.111, speed 639.73 f/s, eps 0.10
# 3010423: done 10 games, mean reward 15.100, speed 203.31 f/s, eps 0.10
# 3011372: done 11 games, mean reward 14.909, speed 114.84 f/s, eps 0.10
# 3012878: done 12 games, mean reward 15.583, speed 118.96 f/s, eps 0.10
# 3013837: done 13 games, mean reward 15.538, speed 120.49 f/s, eps 0.10
# 3014609: done 14 games, mean reward 15.357, speed 120.56 f/s, eps 0.10
# 3014885: done 15 games, mean reward 14.400, speed 120.35 f/s, eps 0.10
# 3017584: done 16 games, mean reward 15.938, speed 128.32 f/s, eps 0.10
# 3017976: done 17 games, mean reward 15.235, speed 122.92 f/s, eps 0.10
# 3019050: done 18 games, mean reward 15.167, speed 129.33 f/s, eps 0.10
# 3019511: done 19 games, mean reward 14.789, speed 129.85 f/s, eps 0.10
# 3023248: done 20 games, mean reward 16.400, speed 123.46 f/s, eps 0.10
# 3024171: done 21 games, mean reward 16.333, speed 126.93 f/s, eps 0.10
# 3026626: done 22 games, mean reward 17.318, speed 127.62 f/s, eps 0.10
# 3027388: done 23 games, mean reward 16.870, speed 123.35 f/s, eps 0.10
# 3028139: done 24 games, mean reward 16.667, speed 123.49 f/s, eps 0.10
# 3028685: done 25 games, mean reward 16.440, speed 122.79 f/s, eps 0.10
# 3029136: done 26 games, mean reward 15.923, speed 125.55 f/s, eps 0.10
# 3030369: done 27 games, mean reward 15.926, speed 126.10 f/s, eps 0.10
# 3030990: done 28 games, mean reward 15.857, speed 125.71 f/s, eps 0.10
# 3031620: done 29 games, mean reward 15.483, speed 128.07 f/s, eps 0.10
# 3032395: done 30 games, mean reward 15.300, speed 125.98 f/s, eps 0.10
# 3033300: done 31 games, mean reward 15.290, speed 127.10 f/s, eps 0.10
# 3035403: done 32 games, mean reward 15.719, speed 129.64 f/s, eps 0.10
# 3035670: done 33 games, mean reward 15.273, speed 132.63 f/s, eps 0.10
# 3036341: done 34 games, mean reward 15.059, speed 125.98 f/s, eps 0.10
# 3036856: done 35 games, mean reward 14.800, speed 125.98 f/s, eps 0.10
# 3037834: done 36 games, mean reward 14.611, speed 129.28 f/s, eps 0.10
# 3038369: done 37 games, mean reward 14.243, speed 127.33 f/s, eps 0.10
# 3040000: done 38 games, mean reward 14.553, speed 124.34 f/s, eps 0.10
# 3040355: done 39 games, mean reward 14.282, speed 129.90 f/s, eps 0.10
# 3041265: done 40 games, mean reward 14.250, speed 126.64 f/s, eps 0.10
# 3042980: done 41 games, mean reward 14.268, speed 129.06 f/s, eps 0.10
# 3043743: done 42 games, mean reward 14.214, speed 129.58 f/s, eps 0.10
# 3043985: done 43 games, mean reward 13.953, speed 127.97 f/s, eps 0.10
# 3045409: done 44 games, mean reward 14.205, speed 128.83 f/s, eps 0.10
# 3045625: done 45 games, mean reward 13.911, speed 129.58 f/s, eps 0.10
# 3046199: done 46 games, mean reward 13.696, speed 129.93 f/s, eps 0.10
# 3047504: done 47 games, mean reward 13.936, speed 127.22 f/s, eps 0.10
# 3047734: done 48 games, mean reward 13.646, speed 124.99 f/s, eps 0.10
# 3048033: done 49 games, mean reward 13.408, speed 129.24 f/s, eps 0.10
# 3049301: done 50 games, mean reward 13.540, speed 128.66 f/s, eps 0.10
# 3049751: done 51 games, mean reward 13.373, speed 129.49 f/s, eps 0.10
# 3050269: done 52 games, mean reward 13.212, speed 127.47 f/s, eps 0.10
# 3051206: done 53 games, mean reward 13.245, speed 129.16 f/s, eps 0.10
# 3052621: done 54 games, mean reward 13.278, speed 117.58 f/s, eps 0.10
# 3053490: done 55 games, mean reward 13.309, speed 125.71 f/s, eps 0.10
# 3055522: done 56 games, mean reward 13.554, speed 125.53 f/s, eps 0.10
# 3056482: done 57 games, mean reward 13.421, speed 126.40 f/s, eps 0.10
# 3058159: done 58 games, mean reward 13.586, speed 127.51 f/s, eps 0.10
# 3060790: done 59 games, mean reward 14.068, speed 125.03 f/s, eps 0.10
# 3062006: done 60 games, mean reward 14.133, speed 124.22 f/s, eps 0.10
# 3062745: done 61 games, mean reward 14.148, speed 121.60 f/s, eps 0.10
# 3064129: done 62 games, mean reward 14.274, speed 126.15 f/s, eps 0.10
# 3064356: done 63 games, mean reward 14.079, speed 131.27 f/s, eps 0.10
# 3064728: done 64 games, mean reward 13.922, speed 130.52 f/s, eps 0.10
# 3066289: done 65 games, mean reward 14.108, speed 127.15 f/s, eps 0.10
# 3066700: done 66 games, mean reward 13.955, speed 125.34 f/s, eps 0.10
# 3067104: done 67 games, mean reward 13.881, speed 127.93 f/s, eps 0.10
# 3067665: done 68 games, mean reward 13.794, speed 126.13 f/s, eps 0.10
# 3068142: done 69 games, mean reward 13.696, speed 124.37 f/s, eps 0.10
# 3069345: done 70 games, mean reward 13.714, speed 126.71 f/s, eps 0.10
# 3071600: done 71 games, mean reward 14.028, speed 127.04 f/s, eps 0.10
# 3072223: done 72 games, mean reward 13.931, speed 124.40 f/s, eps 0.10
# 3072558: done 73 games, mean reward 13.767, speed 127.35 f/s, eps 0.10
# 3074269: done 74 games, mean reward 13.986, speed 127.69 f/s, eps 0.10
# 3074876: done 75 games, mean reward 13.893, speed 126.69 f/s, eps 0.10
# 3075369: done 76 games, mean reward 13.789, speed 126.84 f/s, eps 0.10
# 3077230: done 77 games, mean reward 13.974, speed 127.24 f/s, eps 0.10
# 3078845: done 78 games, mean reward 14.000, speed 126.55 f/s, eps 0.10
# 3079533: done 79 games, mean reward 13.911, speed 124.89 f/s, eps 0.10
# 3080551: done 80 games, mean reward 13.925, speed 128.66 f/s, eps 0.10
# 3082578: done 81 games, mean reward 14.037, speed 125.48 f/s, eps 0.10
# 3083187: done 82 games, mean reward 13.951, speed 126.19 f/s, eps 0.10
# 3085252: done 83 games, mean reward 14.024, speed 126.14 f/s, eps 0.10
# 3085722: done 84 games, mean reward 13.917, speed 127.76 f/s, eps 0.10
# 3086090: done 85 games, mean reward 13.800, speed 130.68 f/s, eps 0.10
# 3088271: done 86 games, mean reward 13.988, speed 128.98 f/s, eps 0.10
# 3089313: done 87 games, mean reward 14.000, speed 125.49 f/s, eps 0.10
# 3089860: done 88 games, mean reward 13.977, speed 129.60 f/s, eps 0.10
# 3090359: done 89 games, mean reward 13.899, speed 126.80 f/s, eps 0.10
# 3091486: done 90 games, mean reward 13.933, speed 128.69 f/s, eps 0.10
# 3092721: done 91 games, mean reward 14.000, speed 128.30 f/s, eps 0.10
# 3093843: done 92 games, mean reward 14.076, speed 127.54 f/s, eps 0.10
# 3094349: done 93 games, mean reward 13.989, speed 130.49 f/s, eps 0.10
# 3094741: done 94 games, mean reward 13.851, speed 127.80 f/s, eps 0.10
# 3096153: done 95 games, mean reward 13.958, speed 126.53 f/s, eps 0.10
# 3096535: done 96 games, mean reward 13.854, speed 126.86 f/s, eps 0.10
# 3097092: done 97 games, mean reward 13.763, speed 124.15 f/s, eps 0.10
# 3099247: done 98 games, mean reward 14.051, speed 115.97 f/s, eps 0.10
# 3099412: done 99 games, mean reward 13.919, speed 106.32 f/s, eps 0.10
# 3100346: done 100 games, mean reward 13.880, speed 112.53 f/s, eps 0.10
# 3102101: done 101 games, mean reward 14.110, speed 126.22 f/s, eps 0.10
# 3102858: done 102 games, mean reward 14.150, speed 133.90 f/s, eps 0.10
# 3103818: done 103 games, mean reward 14.040, speed 126.64 f/s, eps 0.10
# 3104500: done 104 games, mean reward 14.130, speed 127.35 f/s, eps 0.10
# 3105262: done 105 games, mean reward 14.150, speed 126.75 f/s, eps 0.10
# 3105956: done 106 games, mean reward 14.050, speed 129.57 f/s, eps 0.10
# 3106462: done 107 games, mean reward 13.790, speed 123.51 f/s, eps 0.10
# 3107231: done 108 games, mean reward 13.440, speed 132.45 f/s, eps 0.10
# 3107912: done 109 games, mean reward 13.540, speed 127.63 f/s, eps 0.10
# 3109134: done 110 games, mean reward 13.620, speed 125.92 f/s, eps 0.10
# 3109819: done 111 games, mean reward 13.560, speed 129.04 f/s, eps 0.10
# 3110782: done 112 games, mean reward 13.450, speed 127.85 f/s, eps 0.10
# 3112368: done 113 games, mean reward 13.550, speed 127.11 f/s, eps 0.10
# 3113498: done 114 games, mean reward 13.510, speed 127.33 f/s, eps 0.10
# 3113812: done 115 games, mean reward 13.530, speed 132.61 f/s, eps 0.10
# 3115538: done 116 games, mean reward 13.390, speed 112.44 f/s, eps 0.10
# 3115820: done 117 games, mean reward 13.360, speed 115.32 f/s, eps 0.10
# 3116221: done 118 games, mean reward 13.260, speed 126.01 f/s, eps 0.10
# 3118025: done 119 games, mean reward 13.500, speed 128.89 f/s, eps 0.10
# 3120566: done 120 games, mean reward 13.430, speed 127.29 f/s, eps 0.10
# 3121010: done 121 games, mean reward 13.320, speed 127.54 f/s, eps 0.10
# 3124137: done 122 games, mean reward 13.490, speed 127.39 f/s, eps 0.10
# 3125254: done 123 games, mean reward 13.560, speed 127.00 f/s, eps 0.10
# 3126432: done 124 games, mean reward 13.620, speed 128.15 f/s, eps 0.10
# 3128082: done 125 games, mean reward 13.780, speed 126.99 f/s, eps 0.10
# 3128316: done 126 games, mean reward 13.770, speed 130.56 f/s, eps 0.10
# 3128791: done 127 games, mean reward 13.640, speed 124.76 f/s, eps 0.10
# 3129250: done 128 games, mean reward 13.580, speed 129.81 f/s, eps 0.10
# 3130779: done 129 games, mean reward 13.810, speed 128.63 f/s, eps 0.10
# 3131090: done 130 games, mean reward 13.730, speed 127.79 f/s, eps 0.10
# 3131771: done 131 games, mean reward 13.720, speed 126.59 f/s, eps 0.10
# 3132507: done 132 games, mean reward 13.580, speed 125.40 f/s, eps 0.10
# 3135497: done 133 games, mean reward 13.980, speed 124.77 f/s, eps 0.10
# 3135694: done 134 games, mean reward 13.900, speed 123.62 f/s, eps 0.10
# 3136647: done 135 games, mean reward 13.990, speed 124.50 f/s, eps 0.10
# 3137206: done 136 games, mean reward 13.980, speed 125.57 f/s, eps 0.10
# 3137618: done 137 games, mean reward 14.000, speed 126.54 f/s, eps 0.10
# 3139351: done 138 games, mean reward 14.010, speed 122.71 f/s, eps 0.10
# 3140718: done 139 games, mean reward 14.150, speed 126.50 f/s, eps 0.10
# 3140985: done 140 games, mean reward 14.040, speed 127.95 f/s, eps 0.10
# 3143124: done 141 games, mean reward 14.330, speed 124.97 f/s, eps 0.10
# 3143349: done 142 games, mean reward 14.220, speed 126.69 f/s, eps 0.10
# 3143995: done 143 games, mean reward 14.310, speed 126.27 f/s, eps 0.10
# 3146564: done 144 games, mean reward 14.470, speed 126.76 f/s, eps 0.10
# 3150064: done 145 games, mean reward 14.950, speed 128.19 f/s, eps 0.10
# 3150243: done 146 games, mean reward 14.910, speed 118.79 f/s, eps 0.10
# 3151745: done 147 games, mean reward 14.960, speed 128.47 f/s, eps 0.10
# 3152468: done 148 games, mean reward 15.110, speed 126.81 f/s, eps 0.10
# 3152882: done 149 games, mean reward 15.130, speed 126.55 f/s, eps 0.10
# 3153898: done 150 games, mean reward 15.080, speed 127.24 f/s, eps 0.10
# 3154184: done 151 games, mean reward 15.060, speed 109.76 f/s, eps 0.10
# 3154853: done 152 games, mean reward 15.100, speed 109.54 f/s, eps 0.10
# 3159142: done 153 games, mean reward 15.700, speed 108.05 f/s, eps 0.10
# 3159337: done 154 games, mean reward 15.560, speed 109.87 f/s, eps 0.10
# 3159613: done 155 games, mean reward 15.480, speed 114.80 f/s, eps 0.10
# 3160595: done 156 games, mean reward 15.360, speed 119.03 f/s, eps 0.10
# 3162298: done 157 games, mean reward 15.600, speed 126.83 f/s, eps 0.10
# 3163874: done 158 games, mean reward 15.650, speed 127.15 f/s, eps 0.10
# 3164690: done 159 games, mean reward 15.380, speed 126.62 f/s, eps 0.10
# 3165423: done 160 games, mean reward 15.320, speed 125.69 f/s, eps 0.10
# 3166305: done 161 games, mean reward 15.200, speed 125.34 f/s, eps 0.10
# 3167180: done 162 games, mean reward 15.130, speed 124.76 f/s, eps 0.10
# 3168127: done 163 games, mean reward 15.260, speed 124.88 f/s, eps 0.10
# 3169787: done 164 games, mean reward 15.530, speed 127.48 f/s, eps 0.10
# 3172911: done 165 games, mean reward 15.800, speed 124.62 f/s, eps 0.10
# 3173455: done 166 games, mean reward 15.850, speed 126.44 f/s, eps 0.10
# 3173937: done 167 games, mean reward 15.850, speed 127.67 f/s, eps 0.10
# 3174712: done 168 games, mean reward 15.920, speed 122.85 f/s, eps 0.10
# 3176305: done 169 games, mean reward 16.150, speed 127.19 f/s, eps 0.10
# 3177537: done 170 games, mean reward 16.160, speed 126.29 f/s, eps 0.10
# 3180881: done 171 games, mean reward 16.250, speed 125.30 f/s, eps 0.10
# 3181640: done 172 games, mean reward 16.320, speed 123.50 f/s, eps 0.10
# 3181879: done 173 games, mean reward 16.320, speed 129.41 f/s, eps 0.10
# 3182276: done 174 games, mean reward 16.060, speed 129.71 f/s, eps 0.10
# 3183820: done 175 games, mean reward 16.220, speed 123.05 f/s, eps 0.10
# 3184239: done 176 games, mean reward 16.190, speed 122.36 f/s, eps 0.10
# 3184850: done 177 games, mean reward 16.000, speed 124.13 f/s, eps 0.10
# 3185803: done 178 games, mean reward 16.020, speed 125.83 f/s, eps 0.10
# 3186842: done 179 games, mean reward 16.090, speed 123.52 f/s, eps 0.10
# 3188349: done 180 games, mean reward 16.230, speed 126.73 f/s, eps 0.10
# 3189718: done 181 games, mean reward 16.250, speed 126.94 f/s, eps 0.10
# 3190195: done 182 games, mean reward 16.220, speed 121.92 f/s, eps 0.10
# 3191881: done 183 games, mean reward 16.270, speed 126.39 f/s, eps 0.10
# 3192590: done 184 games, mean reward 16.370, speed 129.68 f/s, eps 0.10
# 3193607: done 185 games, mean reward 16.480, speed 126.02 f/s, eps 0.10
# 3194565: done 186 games, mean reward 16.290, speed 126.06 f/s, eps 0.10
# 3197222: done 187 games, mean reward 16.580, speed 125.97 f/s, eps 0.10
# 3197988: done 188 games, mean reward 16.530, speed 125.23 f/s, eps 0.10
# 3199023: done 189 games, mean reward 16.640, speed 110.22 f/s, eps 0.10
# 3199785: done 190 games, mean reward 16.620, speed 110.85 f/s, eps 0.10
# 3200182: done 191 games, mean reward 16.480, speed 112.07 f/s, eps 0.10
# 3200915: done 192 games, mean reward 16.360, speed 110.52 f/s, eps 0.10
# 3202081: done 193 games, mean reward 16.480, speed 110.05 f/s, eps 0.10
# 3204820: done 194 games, mean reward 16.990, speed 127.92 f/s, eps 0.10
# 3205270: done 195 games, mean reward 16.800, speed 129.35 f/s, eps 0.10
# 3205676: done 196 games, mean reward 16.850, speed 123.50 f/s, eps 0.10
# 3207671: done 197 games, mean reward 17.080, speed 128.83 f/s, eps 0.10
# 3208659: done 198 games, mean reward 16.800, speed 125.31 f/s, eps 0.10
# 3211196: done 199 games, mean reward 17.230, speed 126.28 f/s, eps 0.10
# 3211377: done 200 games, mean reward 17.130, speed 129.70 f/s, eps 0.10
# 3212754: done 201 games, mean reward 17.050, speed 125.96 f/s, eps 0.10
# 3213917: done 202 games, mean reward 17.110, speed 125.24 f/s, eps 0.10
# 3214687: done 203 games, mean reward 17.180, speed 130.69 f/s, eps 0.10
# 3214950: done 204 games, mean reward 17.040, speed 128.13 f/s, eps 0.10
# 3216919: done 205 games, mean reward 17.290, speed 127.64 f/s, eps 0.10
# 3217492: done 206 games, mean reward 17.340, speed 126.51 f/s, eps 0.10
# 3217667: done 207 games, mean reward 17.240, speed 126.04 f/s, eps 0.10
# 3218300: done 208 games, mean reward 17.350, speed 123.66 f/s, eps 0.10
# 3219156: done 209 games, mean reward 17.360, speed 126.76 f/s, eps 0.10
# 3219316: done 210 games, mean reward 17.130, speed 126.89 f/s, eps 0.10
# 3223068: done 211 games, mean reward 17.680, speed 126.63 f/s, eps 0.10
# 3223336: done 212 games, mean reward 17.590, speed 126.10 f/s, eps 0.10
# 3223697: done 213 games, mean reward 17.380, speed 122.97 f/s, eps 0.10
# 3224274: done 214 games, mean reward 17.410, speed 124.12 f/s, eps 0.10
# 3225900: done 215 games, mean reward 17.560, speed 125.73 f/s, eps 0.10
# 3226654: done 216 games, mean reward 17.450, speed 128.18 f/s, eps 0.10
# 3228088: done 217 games, mean reward 17.650, speed 126.06 f/s, eps 0.10
# 3229369: done 218 games, mean reward 17.720, speed 118.45 f/s, eps 0.10
# 3230934: done 219 games, mean reward 17.690, speed 112.29 f/s, eps 0.10
# 3231711: done 220 games, mean reward 17.440, speed 126.83 f/s, eps 0.10
# 3233260: done 221 games, mean reward 17.630, speed 126.04 f/s, eps 0.10
# 3233684: done 222 games, mean reward 17.110, speed 123.21 f/s, eps 0.10
# 3234557: done 223 games, mean reward 17.120, speed 124.68 f/s, eps 0.10
# 3234962: done 224 games, mean reward 17.020, speed 124.86 f/s, eps 0.10
# 3235355: done 225 games, mean reward 16.800, speed 125.67 f/s, eps 0.10
# 3236672: done 226 games, mean reward 16.930, speed 125.62 f/s, eps 0.10
# 3238005: done 227 games, mean reward 17.160, speed 128.01 f/s, eps 0.10
# 3238326: done 228 games, mean reward 17.120, speed 124.53 f/s, eps 0.10
# 3239532: done 229 games, mean reward 16.990, speed 128.85 f/s, eps 0.10
# 3240379: done 230 games, mean reward 17.110, speed 127.17 f/s, eps 0.10
# 3242783: done 231 games, mean reward 17.380, speed 128.51 f/s, eps 0.10
# 3244584: done 232 games, mean reward 17.550, speed 127.47 f/s, eps 0.10
# 3244869: done 233 games, mean reward 17.160, speed 124.10 f/s, eps 0.10
# 3245134: done 234 games, mean reward 17.180, speed 127.52 f/s, eps 0.10
# 3248487: done 235 games, mean reward 17.610, speed 125.89 f/s, eps 0.10
# 3250715: done 236 games, mean reward 17.880, speed 126.79 f/s, eps 0.10
# 3251328: done 237 games, mean reward 18.000, speed 122.76 f/s, eps 0.10
# 3252779: done 238 games, mean reward 17.980, speed 128.18 f/s, eps 0.10
# 3253192: done 239 games, mean reward 17.850, speed 120.14 f/s, eps 0.10
# 3255245: done 240 games, mean reward 18.150, speed 120.88 f/s, eps 0.10
# 3256668: done 241 games, mean reward 17.970, speed 128.10 f/s, eps 0.10
# 3257600: done 242 games, mean reward 18.110, speed 124.26 f/s, eps 0.10
# 3258405: done 243 games, mean reward 18.100, speed 126.95 f/s, eps 0.10
# 3259136: done 244 games, mean reward 17.840, speed 125.56 f/s, eps 0.10
# 3259757: done 245 games, mean reward 17.450, speed 129.54 f/s, eps 0.10
# 3261075: done 246 games, mean reward 17.620, speed 126.01 f/s, eps 0.10
# 3262904: done 247 games, mean reward 17.610, speed 124.58 f/s, eps 0.10
# 3264225: done 248 games, mean reward 17.620, speed 109.48 f/s, eps 0.10
# 3265078: done 249 games, mean reward 17.720, speed 110.02 f/s, eps 0.10
# 3265800: done 250 games, mean reward 17.720, speed 112.61 f/s, eps 0.10
# 3266943: done 251 games, mean reward 17.870, speed 109.84 f/s, eps 0.10
# 3267482: done 252 games, mean reward 17.870, speed 109.67 f/s, eps 0.10
# 3268573: done 253 games, mean reward 17.320, speed 109.86 f/s, eps 0.10
# 3269914: done 254 games, mean reward 17.500, speed 110.42 f/s, eps 0.10
# 3270189: done 255 games, mean reward 17.460, speed 123.54 f/s, eps 0.10
# 3272642: done 256 games, mean reward 17.720, speed 126.10 f/s, eps 0.10
# 3274182: done 257 games, mean reward 17.710, speed 125.46 f/s, eps 0.10
# 3274477: done 258 games, mean reward 17.480, speed 128.67 f/s, eps 0.10
# 3276769: done 259 games, mean reward 17.700, speed 123.87 f/s, eps 0.10
# 3278086: done 260 games, mean reward 17.790, speed 128.06 f/s, eps 0.10
# 3278985: done 261 games, mean reward 17.910, speed 130.40 f/s, eps 0.10
# 3282150: done 262 games, mean reward 18.290, speed 128.22 f/s, eps 0.10
# 3282764: done 263 games, mean reward 18.220, speed 123.99 f/s, eps 0.10
# 3284154: done 264 games, mean reward 18.150, speed 124.32 f/s, eps 0.10
# 3285214: done 265 games, mean reward 17.790, speed 126.69 f/s, eps 0.10
# 3286692: done 266 games, mean reward 17.960, speed 126.53 f/s, eps 0.10
# 3287588: done 267 games, mean reward 18.040, speed 126.58 f/s, eps 0.10
# 3287790: done 268 games, mean reward 17.900, speed 130.11 f/s, eps 0.10
# 3288523: done 269 games, mean reward 17.750, speed 129.44 f/s, eps 0.10
# 3288867: done 270 games, mean reward 17.640, speed 129.62 f/s, eps 0.10
# 3289272: done 271 games, mean reward 17.230, speed 126.82 f/s, eps 0.10
# 3290087: done 272 games, mean reward 17.240, speed 127.15 f/s, eps 0.10
# 3290651: done 273 games, mean reward 17.320, speed 123.77 f/s, eps 0.10
# 3292721: done 274 games, mean reward 17.580, speed 128.20 f/s, eps 0.10
# 3293634: done 275 games, mean reward 17.500, speed 129.46 f/s, eps 0.10
# 3295346: done 276 games, mean reward 17.750, speed 127.18 f/s, eps 0.10
# 3296147: done 277 games, mean reward 17.790, speed 126.96 f/s, eps 0.10
# 3297587: done 278 games, mean reward 17.880, speed 126.69 f/s, eps 0.10
# 3298840: done 279 games, mean reward 17.900, speed 124.87 f/s, eps 0.10
# 3299974: done 280 games, mean reward 17.790, speed 127.11 f/s, eps 0.10
# 3301305: done 281 games, mean reward 17.830, speed 110.43 f/s, eps 0.10
# 3302081: done 282 games, mean reward 17.890, speed 115.85 f/s, eps 0.10
# 3302471: done 283 games, mean reward 17.680, speed 123.67 f/s, eps 0.10
# 3305376: done 284 games, mean reward 17.960, speed 116.51 f/s, eps 0.10
# 3306188: done 285 games, mean reward 17.890, speed 100.51 f/s, eps 0.10
# 3307198: done 286 games, mean reward 17.910, speed 104.95 f/s, eps 0.10
# 3307891: done 287 games, mean reward 17.620, speed 114.94 f/s, eps 0.10
# 3308128: done 288 games, mean reward 17.560, speed 106.40 f/s, eps 0.10
# 3308482: done 289 games, mean reward 17.420, speed 107.89 f/s, eps 0.10
# 3308991: done 290 games, mean reward 17.350, speed 110.42 f/s, eps 0.10
# 3309930: done 291 games, mean reward 17.400, speed 100.86 f/s, eps 0.10
# 3311628: done 292 games, mean reward 17.570, speed 103.09 f/s, eps 0.10
# 3312599: done 293 games, mean reward 17.570, speed 111.40 f/s, eps 0.10
# 3313125: done 294 games, mean reward 17.130, speed 107.92 f/s, eps 0.10
# 3315415: done 295 games, mean reward 17.420, speed 107.07 f/s, eps 0.10
# 3316048: done 296 games, mean reward 17.480, speed 110.55 f/s, eps 0.10
# 3316627: done 297 games, mean reward 17.300, speed 113.43 f/s, eps 0.10
# 3317199: done 298 games, mean reward 17.210, speed 103.63 f/s, eps 0.10
# 3317740: done 299 games, mean reward 16.820, speed 106.35 f/s, eps 0.10
# 3317953: done 300 games, mean reward 16.820, speed 104.63 f/s, eps 0.10
# 3318685: done 301 games, mean reward 16.700, speed 103.09 f/s, eps 0.10
# 3320628: done 302 games, mean reward 16.830, speed 104.61 f/s, eps 0.10
# 3321679: done 303 games, mean reward 16.890, speed 105.89 f/s, eps 0.10
# 3322364: done 304 games, mean reward 17.000, speed 119.43 f/s, eps 0.10
# 3323719: done 305 games, mean reward 16.890, speed 107.41 f/s, eps 0.10
# 3325048: done 306 games, mean reward 16.990, speed 97.62 f/s, eps 0.10
# 3326008: done 307 games, mean reward 17.150, speed 112.35 f/s, eps 0.10
# 3326221: done 308 games, mean reward 17.010, speed 117.23 f/s, eps 0.10
# 3326975: done 309 games, mean reward 17.030, speed 105.75 f/s, eps 0.10
# 3328265: done 310 games, mean reward 17.220, speed 109.80 f/s, eps 0.10
# 3330007: done 311 games, mean reward 16.870, speed 113.11 f/s, eps 0.10
# 3331665: done 312 games, mean reward 17.100, speed 112.46 f/s, eps 0.10
# 3333451: done 313 games, mean reward 17.260, speed 112.97 f/s, eps 0.10
# 3334080: done 314 games, mean reward 17.210, speed 108.86 f/s, eps 0.10
# 3334700: done 315 games, mean reward 17.180, speed 99.22 f/s, eps 0.10
# 3336104: done 316 games, mean reward 17.240, speed 100.88 f/s, eps 0.10
# 3338944: done 317 games, mean reward 17.510, speed 103.95 f/s, eps 0.10
# 3340074: done 318 games, mean reward 17.610, speed 109.33 f/s, eps 0.10
# 3340600: done 319 games, mean reward 17.410, speed 104.16 f/s, eps 0.10
# 3341605: done 320 games, mean reward 17.410, speed 112.80 f/s, eps 0.10
# 3343056: done 321 games, mean reward 17.460, speed 114.90 f/s, eps 0.10
# 3343318: done 322 games, mean reward 17.440, speed 111.95 f/s, eps 0.10
# 3343529: done 323 games, mean reward 17.300, speed 105.53 f/s, eps 0.10
# 3345141: done 324 games, mean reward 17.480, speed 111.11 f/s, eps 0.10
# 3345991: done 325 games, mean reward 17.530, speed 112.34 f/s, eps 0.10
# 3346553: done 326 games, mean reward 17.470, speed 113.61 f/s, eps 0.10
# 3349534: done 327 games, mean reward 17.710, speed 106.73 f/s, eps 0.10
# 3349818: done 328 games, mean reward 17.700, speed 79.45 f/s, eps 0.10
# 3350156: done 329 games, mean reward 17.580, speed 113.49 f/s, eps 0.10
# 3351598: done 330 games, mean reward 17.700, speed 111.34 f/s, eps 0.10
# 3351884: done 331 games, mean reward 17.320, speed 119.45 f/s, eps 0.10
# 3352213: done 332 games, mean reward 17.010, speed 99.20 f/s, eps 0.10
# 3353062: done 333 games, mean reward 17.140, speed 104.56 f/s, eps 0.10
# 3353498: done 334 games, mean reward 17.200, speed 115.07 f/s, eps 0.10
# 3353863: done 335 games, mean reward 16.680, speed 106.91 f/s, eps 0.10
# 3354430: done 336 games, mean reward 16.410, speed 105.39 f/s, eps 0.10
# 3354658: done 337 games, mean reward 16.290, speed 94.03 f/s, eps 0.10
# 3357890: done 338 games, mean reward 16.520, speed 109.26 f/s, eps 0.10
# 3358240: done 339 games, mean reward 16.510, speed 103.86 f/s, eps 0.10
# 3360170: done 340 games, mean reward 16.450, speed 111.43 f/s, eps 0.10
# 3360739: done 341 games, mean reward 16.300, speed 91.07 f/s, eps 0.10
# 3361414: done 342 games, mean reward 16.290, speed 92.12 f/s, eps 0.10
# 3362544: done 343 games, mean reward 16.320, speed 113.85 f/s, eps 0.10
# 3362957: done 344 games, mean reward 16.190, speed 114.95 f/s, eps 0.10
# 3363523: done 345 games, mean reward 16.150, speed 117.83 f/s, eps 0.10
# 3364718: done 346 games, mean reward 16.170, speed 107.42 f/s, eps 0.10
# 3365350: done 347 games, mean reward 15.930, speed 109.39 f/s, eps 0.10
# 3367589: done 348 games, mean reward 16.180, speed 106.28 f/s, eps 0.10
# 3368348: done 349 games, mean reward 16.110, speed 111.19 f/s, eps 0.10
# 3369873: done 350 games, mean reward 16.220, speed 103.35 f/s, eps 0.10
# 3372080: done 351 games, mean reward 16.400, speed 109.50 f/s, eps 0.10
# 3373220: done 352 games, mean reward 16.490, speed 106.32 f/s, eps 0.10
# 3374015: done 353 games, mean reward 16.440, speed 109.67 f/s, eps 0.10
# 3375387: done 354 games, mean reward 16.430, speed 106.84 f/s, eps 0.10
# 3377457: done 355 games, mean reward 16.630, speed 117.37 f/s, eps 0.10
# 3377715: done 356 games, mean reward 16.240, speed 106.10 f/s, eps 0.10
# 3378399: done 357 games, mean reward 16.100, speed 115.05 f/s, eps 0.10
# 3378796: done 358 games, mean reward 16.110, speed 115.46 f/s, eps 0.10
# 3380001: done 359 games, mean reward 15.940, speed 110.42 f/s, eps 0.10
# 3381546: done 360 games, mean reward 16.030, speed 110.35 f/s, eps 0.10
# 3382078: done 361 games, mean reward 15.980, speed 108.02 f/s, eps 0.10
# 3382455: done 362 games, mean reward 15.500, speed 107.40 f/s, eps 0.10
# 3383403: done 363 games, mean reward 15.570, speed 108.22 f/s, eps 0.10
# 3384281: done 364 games, mean reward 15.440, speed 114.95 f/s, eps 0.10
# 3384706: done 365 games, mean reward 15.290, speed 106.17 f/s, eps 0.10
# 3385802: done 366 games, mean reward 15.230, speed 103.24 f/s, eps 0.10
# 3386125: done 367 games, mean reward 15.080, speed 102.66 f/s, eps 0.10
# 3386362: done 368 games, mean reward 15.070, speed 105.20 f/s, eps 0.10
# 3387858: done 369 games, mean reward 15.220, speed 118.58 f/s, eps 0.10
# 3388370: done 370 games, mean reward 15.290, speed 87.33 f/s, eps 0.10
# 3389314: done 371 games, mean reward 15.400, speed 108.49 f/s, eps 0.10
# 3391758: done 372 games, mean reward 15.640, speed 104.87 f/s, eps 0.10
# 3392142: done 373 games, mean reward 15.600, speed 108.95 f/s, eps 0.10
# 3392652: done 374 games, mean reward 15.420, speed 100.32 f/s, eps 0.10
# 3393504: done 375 games, mean reward 15.350, speed 105.61 f/s, eps 0.10
# 3394401: done 376 games, mean reward 15.240, speed 113.99 f/s, eps 0.10
# 3395391: done 377 games, mean reward 15.230, speed 108.62 f/s, eps 0.10
# 3395568: done 378 games, mean reward 14.960, speed 114.09 f/s, eps 0.10
# 3397734: done 379 games, mean reward 15.240, speed 107.59 f/s, eps 0.10
# 3399027: done 380 games, mean reward 15.200, speed 107.59 f/s, eps 0.10
# 3400758: done 381 games, mean reward 15.090, speed 108.45 f/s, eps 0.10
# 3402426: done 382 games, mean reward 15.270, speed 110.50 f/s, eps 0.10
# 3403009: done 383 games, mean reward 15.250, speed 108.43 f/s, eps 0.10
# 3403178: done 384 games, mean reward 14.820, speed 114.04 f/s, eps 0.10
# 3406989: done 385 games, mean reward 15.330, speed 110.92 f/s, eps 0.10
# 3407253: done 386 games, mean reward 15.210, speed 107.36 f/s, eps 0.10
# 3407445: done 387 games, mean reward 15.060, speed 113.42 f/s, eps 0.10
# 3409708: done 388 games, mean reward 15.450, speed 101.92 f/s, eps 0.10
# 3412071: done 389 games, mean reward 15.760, speed 110.11 f/s, eps 0.10
# 3412244: done 390 games, mean reward 15.690, speed 89.32 f/s, eps 0.10
# 3413024: done 391 games, mean reward 15.730, speed 101.47 f/s, eps 0.10
# 3413969: done 392 games, mean reward 15.620, speed 113.57 f/s, eps 0.10
# 3414893: done 393 games, mean reward 15.590, speed 100.52 f/s, eps 0.10
# 3416222: done 394 games, mean reward 15.710, speed 107.68 f/s, eps 0.10
# 3416510: done 395 games, mean reward 15.390, speed 94.52 f/s, eps 0.10
# 3417614: done 396 games, mean reward 15.400, speed 104.00 f/s, eps 0.10
# 3418398: done 397 games, mean reward 15.450, speed 104.60 f/s, eps 0.10
# 3419206: done 398 games, mean reward 15.530, speed 106.23 f/s, eps 0.10
# 3419829: done 399 games, mean reward 15.520, speed 100.11 f/s, eps 0.10
# 3420766: done 400 games, mean reward 15.670, speed 115.17 f/s, eps 0.10
# 3422318: done 401 games, mean reward 15.820, speed 108.13 f/s, eps 0.10
# 3422481: done 402 games, mean reward 15.510, speed 102.54 f/s, eps 0.10
# 3423665: done 403 games, mean reward 15.540, speed 110.52 f/s, eps 0.10
# 3424159: done 404 games, mean reward 15.490, speed 105.49 f/s, eps 0.10
# 3424330: done 405 games, mean reward 15.270, speed 100.06 f/s, eps 0.10
# 3425218: done 406 games, mean reward 15.220, speed 105.98 f/s, eps 0.10
# 3425568: done 407 games, mean reward 15.110, speed 105.34 f/s, eps 0.10
# 3426071: done 408 games, mean reward 15.190, speed 111.25 f/s, eps 0.10
# 3427521: done 409 games, mean reward 15.310, speed 105.46 f/s, eps 0.10
# 3427727: done 410 games, mean reward 15.120, speed 111.84 f/s, eps 0.10
# 3427921: done 411 games, mean reward 14.870, speed 111.06 f/s, eps 0.10
# 3428361: done 412 games, mean reward 14.650, speed 122.55 f/s, eps 0.10
# 3430372: done 413 games, mean reward 14.730, speed 114.79 f/s, eps 0.10
# 3431580: done 414 games, mean reward 14.890, speed 111.78 f/s, eps 0.10
# 3434660: done 415 games, mean reward 15.260, speed 99.09 f/s, eps 0.10
# 3434961: done 416 games, mean reward 15.090, speed 104.94 f/s, eps 0.10
# 3435255: done 417 games, mean reward 14.650, speed 107.81 f/s, eps 0.10
# 3438845: done 418 games, mean reward 15.010, speed 106.66 f/s, eps 0.10
# 3439230: done 419 games, mean reward 14.950, speed 95.42 f/s, eps 0.10
# 3439622: done 420 games, mean reward 14.860, speed 114.86 f/s, eps 0.10
# 3440446: done 421 games, mean reward 14.730, speed 114.93 f/s, eps 0.10
# 3441168: done 422 games, mean reward 14.850, speed 108.06 f/s, eps 0.10
# 3441363: done 423 games, mean reward 14.850, speed 120.81 f/s, eps 0.10
# 3442320: done 424 games, mean reward 14.800, speed 117.95 f/s, eps 0.10
# 3442481: done 425 games, mean reward 14.700, speed 116.67 f/s, eps 0.10
# 3444724: done 426 games, mean reward 14.970, speed 115.75 f/s, eps 0.10
# 3445813: done 427 games, mean reward 14.660, speed 116.70 f/s, eps 0.10
# 3446050: done 428 games, mean reward 14.650, speed 116.14 f/s, eps 0.10
# 3446472: done 429 games, mean reward 14.690, speed 121.17 f/s, eps 0.10
# 3447680: done 430 games, mean reward 14.660, speed 117.35 f/s, eps 0.10
# 3448425: done 431 games, mean reward 14.700, speed 114.48 f/s, eps 0.10
# 3449698: done 432 games, mean reward 14.840, speed 120.89 f/s, eps 0.10
# 3451316: done 433 games, mean reward 14.990, speed 111.91 f/s, eps 0.10
# 3452410: done 434 games, mean reward 15.060, speed 107.59 f/s, eps 0.10
# 3452653: done 435 games, mean reward 15.030, speed 112.61 f/s, eps 0.10
# 3455956: done 436 games, mean reward 15.530, speed 112.73 f/s, eps 0.10
# 3456237: done 437 games, mean reward 15.540, speed 109.85 f/s, eps 0.10
# 3456383: done 438 games, mean reward 15.060, speed 114.48 f/s, eps 0.10
# 3458451: done 439 games, mean reward 15.390, speed 110.41 f/s, eps 0.10
# 3458722: done 440 games, mean reward 15.150, speed 123.43 f/s, eps 0.10
# 3458929: done 441 games, mean reward 15.050, speed 114.10 f/s, eps 0.10
# 3459713: done 442 games, mean reward 15.060, speed 114.74 f/s, eps 0.10
# 3461063: done 443 games, mean reward 15.090, speed 114.04 f/s, eps 0.10
# 3461573: done 444 games, mean reward 15.150, speed 113.98 f/s, eps 0.10
# 3463675: done 445 games, mean reward 15.380, speed 117.22 f/s, eps 0.10
# 3463975: done 446 games, mean reward 15.200, speed 116.78 f/s, eps 0.10
# 3464448: done 447 games, mean reward 15.240, speed 109.94 f/s, eps 0.10
# 3465022: done 448 games, mean reward 14.910, speed 112.03 f/s, eps 0.10
# 3465536: done 449 games, mean reward 14.910, speed 114.52 f/s, eps 0.10
# 3465902: done 450 games, mean reward 14.730, speed 115.04 f/s, eps 0.10
# 3467652: done 451 games, mean reward 14.660, speed 119.59 f/s, eps 0.10
# 3469148: done 452 games, mean reward 14.640, speed 115.12 f/s, eps 0.10
# 3469731: done 453 games, mean reward 14.590, speed 114.35 f/s, eps 0.10
# 3470623: done 454 games, mean reward 14.560, speed 118.21 f/s, eps 0.10
# 3471795: done 455 games, mean reward 14.480, speed 118.04 f/s, eps 0.10
# 3472893: done 456 games, mean reward 14.650, speed 113.38 f/s, eps 0.10
# 3473280: done 457 games, mean reward 14.560, speed 110.54 f/s, eps 0.10
# 3473511: done 458 games, mean reward 14.510, speed 112.87 f/s, eps 0.10
# 3474194: done 459 games, mean reward 14.390, speed 123.26 f/s, eps 0.10
# 3476700: done 460 games, mean reward 14.480, speed 115.91 f/s, eps 0.10
# 3477083: done 461 games, mean reward 14.420, speed 122.54 f/s, eps 0.10
# 3477419: done 462 games, mean reward 14.390, speed 121.63 f/s, eps 0.10
# 3477880: done 463 games, mean reward 14.320, speed 114.09 f/s, eps 0.10
# 3479160: done 464 games, mean reward 14.430, speed 114.31 f/s, eps 0.10
# 3480492: done 465 games, mean reward 14.690, speed 115.76 f/s, eps 0.10
# 3481052: done 466 games, mean reward 14.570, speed 114.34 f/s, eps 0.10
# 3483840: done 467 games, mean reward 15.050, speed 113.79 f/s, eps 0.10
# 3484806: done 468 games, mean reward 15.210, speed 114.46 f/s, eps 0.10
# 3486192: done 469 games, mean reward 15.180, speed 108.77 f/s, eps 0.10
# 3486466: done 470 games, mean reward 15.090, speed 120.37 f/s, eps 0.10
# 3486682: done 471 games, mean reward 14.950, speed 112.54 f/s, eps 0.10
# 3487478: done 472 games, mean reward 14.710, speed 113.83 f/s, eps 0.10
# 3490451: done 473 games, mean reward 15.270, speed 112.80 f/s, eps 0.10
# 3490987: done 474 games, mean reward 15.210, speed 107.17 f/s, eps 0.10
# 3492236: done 475 games, mean reward 15.330, speed 116.52 f/s, eps 0.10
# 3492410: done 476 games, mean reward 15.160, speed 116.83 f/s, eps 0.10
# 3493475: done 477 games, mean reward 15.130, speed 117.31 f/s, eps 0.10
# 3496526: done 478 games, mean reward 15.630, speed 115.39 f/s, eps 0.10
# 3497066: done 479 games, mean reward 15.290, speed 120.31 f/s, eps 0.10
# 3497238: done 480 games, mean reward 15.150, speed 105.46 f/s, eps 0.10
# 3498998: done 481 games, mean reward 15.270, speed 117.42 f/s, eps 0.10
# 3499386: done 482 games, mean reward 15.020, speed 106.18 f/s, eps 0.10
# 3499772: done 483 games, mean reward 15.070, speed 108.64 f/s, eps 0.10
# 3500710: done 484 games, mean reward 15.220, speed 113.20 f/s, eps 0.10
# 3501000: done 485 games, mean reward 14.680, speed 105.54 f/s, eps 0.10
# 3501841: done 486 games, mean reward 14.770, speed 109.88 f/s, eps 0.10
# 3503882: done 487 games, mean reward 15.070, speed 109.00 f/s, eps 0.10
# 3504413: done 488 games, mean reward 14.750, speed 110.30 f/s, eps 0.10
# 3504982: done 489 games, mean reward 14.470, speed 117.31 f/s, eps 0.10
# 3505812: done 490 games, mean reward 14.610, speed 113.83 f/s, eps 0.10
# 3507755: done 491 games, mean reward 14.740, speed 111.30 f/s, eps 0.10
# 3508547: done 492 games, mean reward 14.700, speed 115.21 f/s, eps 0.10
# 3509417: done 493 games, mean reward 14.700, speed 115.16 f/s, eps 0.10
# 3509761: done 494 games, mean reward 14.560, speed 112.46 f/s, eps 0.10
# 3511514: done 495 games, mean reward 14.780, speed 108.16 f/s, eps 0.10
# 3512874: done 496 games, mean reward 14.880, speed 115.33 f/s, eps 0.10
# 3513142: done 497 games, mean reward 14.760, speed 104.61 f/s, eps 0.10
# 3514308: done 498 games, mean reward 14.740, speed 115.93 f/s, eps 0.10
# 3514888: done 499 games, mean reward 14.820, speed 121.72 f/s, eps 0.10
# 3515653: done 500 games, mean reward 14.760, speed 118.09 f/s, eps 0.10
# 3516062: done 501 games, mean reward 14.560, speed 112.87 f/s, eps 0.10
# 3517459: done 502 games, mean reward 14.780, speed 115.02 f/s, eps 0.10
# 3518938: done 503 games, mean reward 14.800, speed 119.14 f/s, eps 0.10
# 3519207: done 504 games, mean reward 14.740, speed 111.52 f/s, eps 0.10
# 3521149: done 505 games, mean reward 15.020, speed 108.78 f/s, eps 0.10
# 3521717: done 506 games, mean reward 14.900, speed 117.54 f/s, eps 0.10
# 3522163: done 507 games, mean reward 14.890, speed 94.86 f/s, eps 0.10
# 3522825: done 508 games, mean reward 14.930, speed 115.84 f/s, eps 0.10
# 3523658: done 509 games, mean reward 14.780, speed 109.59 f/s, eps 0.10
# 3524734: done 510 games, mean reward 14.910, speed 113.92 f/s, eps 0.10
# 3525550: done 511 games, mean reward 15.040, speed 111.96 f/s, eps 0.10
# 3527088: done 512 games, mean reward 15.250, speed 114.22 f/s, eps 0.10
# 3527555: done 513 games, mean reward 15.020, speed 114.24 f/s, eps 0.10
# 3528462: done 514 games, mean reward 14.940, speed 115.69 f/s, eps 0.10
# 3529196: done 515 games, mean reward 14.500, speed 120.27 f/s, eps 0.10
# 3530342: done 516 games, mean reward 14.600, speed 108.61 f/s, eps 0.10
# 3533196: done 517 games, mean reward 15.010, speed 112.13 f/s, eps 0.10
# 3533768: done 518 games, mean reward 14.540, speed 116.56 f/s, eps 0.10
# 3534971: done 519 games, mean reward 14.630, speed 111.64 f/s, eps 0.10
# 3535769: done 520 games, mean reward 14.720, speed 116.01 f/s, eps 0.10
# 3536644: done 521 games, mean reward 14.720, speed 112.05 f/s, eps 0.10
# 3537367: done 522 games, mean reward 14.740, speed 113.13 f/s, eps 0.10
# 3539449: done 523 games, mean reward 15.030, speed 119.70 f/s, eps 0.10
# 3539979: done 524 games, mean reward 14.900, speed 108.30 f/s, eps 0.10
# 3540543: done 525 games, mean reward 14.960, speed 121.33 f/s, eps 0.10
# 3543064: done 526 games, mean reward 15.040, speed 116.59 f/s, eps 0.10
# 3544161: done 527 games, mean reward 14.960, speed 109.47 f/s, eps 0.10
# 3544693: done 528 games, mean reward 14.980, speed 115.92 f/s, eps 0.10
# 3545972: done 529 games, mean reward 15.120, speed 111.25 f/s, eps 0.10
# 3547237: done 530 games, mean reward 15.080, speed 112.13 f/s, eps 0.10
# 3548395: done 531 games, mean reward 15.150, speed 117.65 f/s, eps 0.10
# 3549286: done 532 games, mean reward 15.150, speed 116.14 f/s, eps 0.10
# 3550026: done 533 games, mean reward 14.970, speed 121.83 f/s, eps 0.10
# 3550412: done 534 games, mean reward 14.850, speed 108.64 f/s, eps 0.10
# 3551163: done 535 games, mean reward 14.960, speed 110.34 f/s, eps 0.10
# 3551803: done 536 games, mean reward 14.470, speed 116.51 f/s, eps 0.10
# 3552579: done 537 games, mean reward 14.510, speed 113.26 f/s, eps 0.10
# 3553804: done 538 games, mean reward 14.710, speed 111.94 f/s, eps 0.10
# 3554107: done 539 games, mean reward 14.350, speed 117.14 f/s, eps 0.10
# 3554606: done 540 games, mean reward 14.420, speed 118.26 f/s, eps 0.10
# 3556205: done 541 games, mean reward 14.680, speed 113.95 f/s, eps 0.10
# 3557137: done 542 games, mean reward 14.670, speed 111.92 f/s, eps 0.10
# 3557317: done 543 games, mean reward 14.500, speed 103.14 f/s, eps 0.10
# 3559416: done 544 games, mean reward 14.730, speed 110.86 f/s, eps 0.10
# 3560165: done 545 games, mean reward 14.530, speed 113.64 f/s, eps 0.10
# 3561977: done 546 games, mean reward 14.810, speed 110.40 f/s, eps 0.10
# 3564510: done 547 games, mean reward 15.160, speed 114.32 f/s, eps 0.10
# 3565209: done 548 games, mean reward 15.180, speed 106.41 f/s, eps 0.10
# 3566462: done 549 games, mean reward 15.320, speed 114.40 f/s, eps 0.10
# 3567310: done 550 games, mean reward 15.350, speed 113.34 f/s, eps 0.10
# 3570112: done 551 games, mean reward 15.470, speed 109.77 f/s, eps 0.10
# 3570602: done 552 games, mean reward 15.400, speed 109.25 f/s, eps 0.10
# 3572073: done 553 games, mean reward 15.580, speed 118.44 f/s, eps 0.10
# 3572643: done 554 games, mean reward 15.470, speed 111.00 f/s, eps 0.10
# 3575186: done 555 games, mean reward 15.760, speed 114.74 f/s, eps 0.10
# 3575711: done 556 games, mean reward 15.650, speed 117.25 f/s, eps 0.10
# 3579173: done 557 games, mean reward 16.140, speed 116.34 f/s, eps 0.10
# 3579421: done 558 games, mean reward 16.160, speed 123.40 f/s, eps 0.10
# 3579643: done 559 games, mean reward 16.100, speed 122.33 f/s, eps 0.10
# 3582260: done 560 games, mean reward 16.110, speed 110.54 f/s, eps 0.10
# 3582421: done 561 games, mean reward 16.070, speed 109.17 f/s, eps 0.10
# 3582815: done 562 games, mean reward 16.100, speed 114.69 f/s, eps 0.10
# 3584204: done 563 games, mean reward 16.220, speed 115.94 f/s, eps 0.10
# 3584863: done 564 games, mean reward 16.100, speed 111.85 f/s, eps 0.10
# 3586564: done 565 games, mean reward 16.100, speed 111.91 f/s, eps 0.10
# 3587625: done 566 games, mean reward 16.230, speed 118.83 f/s, eps 0.10
# 3588306: done 567 games, mean reward 15.810, speed 119.81 f/s, eps 0.10
# 3588935: done 568 games, mean reward 15.690, speed 116.96 f/s, eps 0.10
# 3590159: done 569 games, mean reward 15.640, speed 116.50 f/s, eps 0.10
# 3592177: done 570 games, mean reward 15.840, speed 112.99 f/s, eps 0.10
# 3592569: done 571 games, mean reward 15.870, speed 104.31 f/s, eps 0.10
# 3594027: done 572 games, mean reward 15.910, speed 113.88 f/s, eps 0.10
# 3595762: done 573 games, mean reward 15.550, speed 115.21 f/s, eps 0.10
# 3596377: done 574 games, mean reward 15.610, speed 117.27 f/s, eps 0.10
# 3596896: done 575 games, mean reward 15.510, speed 115.59 f/s, eps 0.10
# 3598248: done 576 games, mean reward 15.710, speed 108.66 f/s, eps 0.10
# 3598464: done 577 games, mean reward 15.640, speed 115.58 f/s, eps 0.10
# 3599893: done 578 games, mean reward 15.390, speed 114.25 f/s, eps 0.10
# 3602305: done 579 games, mean reward 15.680, speed 111.70 f/s, eps 0.10
# 3603141: done 580 games, mean reward 15.830, speed 110.08 f/s, eps 0.10
# 3604133: done 581 games, mean reward 15.720, speed 114.07 f/s, eps 0.10
# 3604849: done 582 games, mean reward 15.770, speed 110.65 f/s, eps 0.10
# 3606830: done 583 games, mean reward 15.930, speed 116.79 f/s, eps 0.10
# 3608850: done 584 games, mean reward 16.080, speed 118.39 f/s, eps 0.10
# 3610091: done 585 games, mean reward 16.270, speed 122.01 f/s, eps 0.10
# 3610347: done 586 games, mean reward 16.210, speed 120.91 f/s, eps 0.10
# 3610984: done 587 games, mean reward 15.950, speed 117.80 f/s, eps 0.10
# 3612580: done 588 games, mean reward 16.170, speed 117.20 f/s, eps 0.10
# 3613400: done 589 games, mean reward 16.230, speed 113.21 f/s, eps 0.10
# 3614198: done 590 games, mean reward 16.180, speed 117.49 f/s, eps 0.10
# 3616198: done 591 games, mean reward 16.280, speed 114.38 f/s, eps 0.10
# 3617393: done 592 games, mean reward 16.380, speed 116.91 f/s, eps 0.10
# 3617710: done 593 games, mean reward 16.260, speed 112.50 f/s, eps 0.10
# 3620052: done 594 games, mean reward 16.640, speed 114.87 f/s, eps 0.10
# 3620251: done 595 games, mean reward 16.410, speed 117.09 f/s, eps 0.10
# 3621584: done 596 games, mean reward 16.320, speed 115.35 f/s, eps 0.10
# 3624920: done 597 games, mean reward 16.830, speed 112.73 f/s, eps 0.10
# 3625119: done 598 games, mean reward 16.720, speed 121.28 f/s, eps 0.10
# 3625328: done 599 games, mean reward 16.600, speed 93.13 f/s, eps 0.10
# 3626149: done 600 games, mean reward 16.660, speed 114.79 f/s, eps 0.10
# 3626831: done 601 games, mean reward 16.760, speed 106.19 f/s, eps 0.10
# 3627464: done 602 games, mean reward 16.690, speed 117.56 f/s, eps 0.10
# 3627928: done 603 games, mean reward 16.540, speed 117.39 f/s, eps 0.10
# 3628163: done 604 games, mean reward 16.560, speed 115.61 f/s, eps 0.10
# 3630196: done 605 games, mean reward 16.590, speed 116.70 f/s, eps 0.10
# 3632157: done 606 games, mean reward 16.860, speed 114.51 f/s, eps 0.10
# 3632518: done 607 games, mean reward 16.880, speed 105.03 f/s, eps 0.10
# 3632811: done 608 games, mean reward 16.770, speed 117.64 f/s, eps 0.10
# 3634252: done 609 games, mean reward 16.850, speed 117.69 f/s, eps 0.10
# 3634672: done 610 games, mean reward 16.780, speed 120.32 f/s, eps 0.10
# 3636691: done 611 games, mean reward 16.940, speed 119.87 f/s, eps 0.10
# 3638122: done 612 games, mean reward 16.950, speed 116.40 f/s, eps 0.10
# 3640519: done 613 games, mean reward 17.230, speed 118.39 f/s, eps 0.10
# 3640832: done 614 games, mean reward 17.090, speed 127.06 f/s, eps 0.10
# 3641453: done 615 games, mean reward 17.160, speed 118.01 f/s, eps 0.10
# 3643210: done 616 games, mean reward 17.280, speed 116.47 f/s, eps 0.10
# 3644151: done 617 games, mean reward 16.960, speed 111.92 f/s, eps 0.10
# 3644957: done 618 games, mean reward 17.010, speed 104.83 f/s, eps 0.10
# 3645788: done 619 games, mean reward 17.020, speed 116.17 f/s, eps 0.10
# 3646754: done 620 games, mean reward 17.010, speed 115.18 f/s, eps 0.10
# 3648014: done 621 games, mean reward 17.070, speed 119.10 f/s, eps 0.10
# 3650346: done 622 games, mean reward 17.380, speed 112.80 f/s, eps 0.10
# 3650753: done 623 games, mean reward 17.130, speed 114.82 f/s, eps 0.10
# 3653409: done 624 games, mean reward 17.500, speed 116.14 f/s, eps 0.10
# 3654155: done 625 games, mean reward 17.550, speed 112.15 f/s, eps 0.10
# 3654329: done 626 games, mean reward 17.120, speed 122.62 f/s, eps 0.10
# 3655848: done 627 games, mean reward 17.290, speed 113.18 f/s, eps 0.10
# 3657686: done 628 games, mean reward 17.580, speed 110.28 f/s, eps 0.10
# 3658011: done 629 games, mean reward 17.400, speed 110.90 f/s, eps 0.10
# 3659704: done 630 games, mean reward 17.510, speed 112.34 f/s, eps 0.10
# 3660040: done 631 games, mean reward 17.430, speed 121.75 f/s, eps 0.10
# 3660671: done 632 games, mean reward 17.370, speed 117.59 f/s, eps 0.10
# 3661136: done 633 games, mean reward 17.350, speed 113.74 f/s, eps 0.10
# 3661529: done 634 games, mean reward 17.370, speed 115.58 f/s, eps 0.10
# 3662723: done 635 games, mean reward 17.390, speed 115.99 f/s, eps 0.10
# 3664040: done 636 games, mean reward 17.530, speed 111.75 f/s, eps 0.10
# 3665000: done 637 games, mean reward 17.530, speed 112.20 f/s, eps 0.10
# 3665307: done 638 games, mean reward 17.370, speed 104.78 f/s, eps 0.10
# 3666628: done 639 games, mean reward 17.580, speed 114.47 f/s, eps 0.10
# 3667215: done 640 games, mean reward 17.570, speed 112.65 f/s, eps 0.10
# 3667367: done 641 games, mean reward 17.300, speed 115.31 f/s, eps 0.10
# 3667970: done 642 games, mean reward 17.240, speed 115.55 f/s, eps 0.10
# 3669001: done 643 games, mean reward 17.380, speed 115.18 f/s, eps 0.10
# 3669417: done 644 games, mean reward 17.150, speed 122.96 f/s, eps 0.10
# 3670907: done 645 games, mean reward 17.280, speed 112.25 f/s, eps 0.10
# 3672412: done 646 games, mean reward 17.210, speed 115.22 f/s, eps 0.10
# 3672687: done 647 games, mean reward 16.780, speed 116.39 f/s, eps 0.10
# 3674330: done 648 games, mean reward 16.970, speed 114.63 f/s, eps 0.10
# 3675075: done 649 games, mean reward 16.880, speed 111.65 f/s, eps 0.10
# 3675276: done 650 games, mean reward 16.790, speed 108.52 f/s, eps 0.10
# 3679491: done 651 games, mean reward 17.100, speed 108.98 f/s, eps 0.10
# 3679802: done 652 games, mean reward 17.060, speed 109.77 f/s, eps 0.10
# 3679967: done 653 games, mean reward 16.780, speed 90.76 f/s, eps 0.10
# 3680635: done 654 games, mean reward 16.890, speed 107.34 f/s, eps 0.10
# 3682870: done 655 games, mean reward 16.850, speed 117.46 f/s, eps 0.10
# 3683050: done 656 games, mean reward 16.770, speed 108.85 f/s, eps 0.10
# 3683905: done 657 games, mean reward 16.360, speed 114.96 f/s, eps 0.10
# 3684518: done 658 games, mean reward 16.400, speed 119.19 f/s, eps 0.10
# 3685111: done 659 games, mean reward 16.470, speed 121.51 f/s, eps 0.10
# 3686507: done 660 games, mean reward 16.280, speed 116.60 f/s, eps 0.10
# 3687538: done 661 games, mean reward 16.370, speed 102.12 f/s, eps 0.10
# 3687964: done 662 games, mean reward 16.390, speed 112.61 f/s, eps 0.10
# 3689207: done 663 games, mean reward 16.380, speed 111.60 f/s, eps 0.10
# 3690340: done 664 games, mean reward 16.410, speed 119.35 f/s, eps 0.10
# 3691102: done 665 games, mean reward 16.260, speed 104.03 f/s, eps 0.10
# 3691920: done 666 games, mean reward 16.200, speed 96.77 f/s, eps 0.10
# 3692354: done 667 games, mean reward 16.180, speed 93.04 f/s, eps 0.10
# 3692980: done 668 games, mean reward 16.230, speed 119.21 f/s, eps 0.10
# ...
# 5775670: done 2667 games, mean reward 18.230, speed 103.54 f/s, eps 0.10
# 5776460: done 2668 games, mean reward 18.390, speed 102.90 f/s, eps 0.10
# 5777111: done 2669 games, mean reward 18.360, speed 117.88 f/s, eps 0.10
# 5778828: done 2670 games, mean reward 18.360, speed 111.46 f/s, eps 0.10
# 5779554: done 2671 games, mean reward 18.150, speed 115.62 f/s, eps 0.10
# 5782544: done 2672 games, mean reward 18.610, speed 116.16 f/s, eps 0.10
# 5782844: done 2673 games, mean reward 18.480, speed 121.46 f/s, eps 0.10
# 5783180: done 2674 games, mean reward 18.260, speed 114.07 f/s, eps 0.10
# 5783927: done 2675 games, mean reward 18.310, speed 104.93 f/s, eps 0.10
# 5784672: done 2676 games, mean reward 18.400, speed 111.75 f/s, eps 0.10
# 5784853: done 2677 games, mean reward 18.400, speed 94.76 f/s, eps 0.10
# 5785473: done 2678 games, mean reward 18.480, speed 103.40 f/s, eps 0.10
# 5786152: done 2679 games, mean reward 18.380, speed 113.77 f/s, eps 0.10
# 5786571: done 2680 games, mean reward 18.230, speed 107.60 f/s, eps 0.10
# 5787251: done 2681 games, mean reward 18.250, speed 111.19 f/s, eps 0.10
# 5788068: done 2682 games, mean reward 18.310, speed 118.58 f/s, eps 0.10
# 5788541: done 2683 games, mean reward 18.360, speed 108.60 f/s, eps 0.10
# 5790945: done 2684 games, mean reward 18.410, speed 112.94 f/s, eps 0.10
# 5791395: done 2685 games, mean reward 18.450, speed 110.21 f/s, eps 0.10
# 5792469: done 2686 games, mean reward 18.640, speed 104.55 f/s, eps 0.10
# 5793404: done 2687 games, mean reward 18.640, speed 112.45 f/s, eps 0.10
# 5794160: done 2688 games, mean reward 18.330, speed 115.71 f/s, eps 0.10
# 5796101: done 2689 games, mean reward 18.630, speed 108.06 f/s, eps 0.10
# 5797690: done 2690 games, mean reward 18.630, speed 106.57 f/s, eps 0.10
# 5799031: done 2691 games, mean reward 18.900, speed 117.55 f/s, eps 0.10
# 5799936: done 2692 games, mean reward 18.950, speed 110.93 f/s, eps 0.10
# 5801218: done 2693 games, mean reward 19.000, speed 113.97 f/s, eps 0.10
# 5801472: done 2694 games, mean reward 18.910, speed 118.29 f/s, eps 0.10
# 5802481: done 2695 games, mean reward 18.890, speed 110.21 f/s, eps 0.10
# 5803293: done 2696 games, mean reward 18.940, speed 116.98 f/s, eps 0.10
# 5803950: done 2697 games, mean reward 18.410, speed 117.14 f/s, eps 0.10
# 5806363: done 2698 games, mean reward 18.670, speed 112.43 f/s, eps 0.10
# 5806889: done 2699 games, mean reward 18.670, speed 117.71 f/s, eps 0.10
# 5807354: done 2700 games, mean reward 18.560, speed 113.39 f/s, eps 0.10
# 5809240: done 2701 games, mean reward 18.530, speed 119.20 f/s, eps 0.10
# 5809700: done 2702 games, mean reward 18.510, speed 109.55 f/s, eps 0.10
# 5812755: done 2703 games, mean reward 18.600, speed 111.78 f/s, eps 0.10
# 5812930: done 2704 games, mean reward 18.350, speed 104.29 f/s, eps 0.10
# 5813821: done 2705 games, mean reward 18.430, speed 113.96 f/s, eps 0.10
# 5815561: done 2706 games, mean reward 18.450, speed 105.88 f/s, eps 0.10
# 5816354: done 2707 games, mean reward 18.600, speed 103.03 f/s, eps 0.10
# 5818018: done 2708 games, mean reward 18.720, speed 116.66 f/s, eps 0.10
# 5820791: done 2709 games, mean reward 18.490, speed 113.86 f/s, eps 0.10
# 5821060: done 2710 games, mean reward 18.450, speed 105.76 f/s, eps 0.10
# 5823447: done 2711 games, mean reward 18.710, speed 116.08 f/s, eps 0.10
# 5824376: done 2712 games, mean reward 18.690, speed 111.65 f/s, eps 0.10
# 5825306: done 2713 games, mean reward 18.470, speed 116.19 f/s, eps 0.10
# 5825843: done 2714 games, mean reward 18.480, speed 110.37 f/s, eps 0.10
# 5826804: done 2715 games, mean reward 18.040, speed 107.62 f/s, eps 0.10
# 5828032: done 2716 games, mean reward 18.200, speed 113.90 f/s, eps 0.10
# 5830702: done 2717 games, mean reward 18.520, speed 112.07 f/s, eps 0.10
# 5832152: done 2718 games, mean reward 18.450, speed 117.08 f/s, eps 0.10
# 5832619: done 2719 games, mean reward 17.970, speed 112.06 f/s, eps 0.10
# 5834236: done 2720 games, mean reward 18.180, speed 112.18 f/s, eps 0.10
# 5835164: done 2721 games, mean reward 18.140, speed 110.00 f/s, eps 0.10
# 5835791: done 2722 games, mean reward 18.040, speed 113.18 f/s, eps 0.10
# 5837879: done 2723 games, mean reward 18.220, speed 115.14 f/s, eps 0.10
# 5838762: done 2724 games, mean reward 18.240, speed 114.79 f/s, eps 0.10
# 5839013: done 2725 games, mean reward 18.100, speed 107.49 f/s, eps 0.10
# 5839787: done 2726 games, mean reward 18.070, speed 107.43 f/s, eps 0.10
# 5840962: done 2727 games, mean reward 17.690, speed 118.44 f/s, eps 0.10
# 5841564: done 2728 games, mean reward 17.710, speed 110.26 f/s, eps 0.10
# 5843378: done 2729 games, mean reward 17.890, speed 108.82 f/s, eps 0.10
# 5844149: done 2730 games, mean reward 17.770, speed 112.58 f/s, eps 0.10
# 5845364: done 2731 games, mean reward 17.410, speed 114.53 f/s, eps 0.10
# 5846214: done 2732 games, mean reward 17.540, speed 114.74 f/s, eps 0.10
# 5846427: done 2733 games, mean reward 17.400, speed 100.61 f/s, eps 0.10
# 5847330: done 2734 games, mean reward 17.430, speed 117.04 f/s, eps 0.10
# 5847864: done 2735 games, mean reward 17.340, speed 121.18 f/s, eps 0.10
# 5848218: done 2736 games, mean reward 16.790, speed 95.47 f/s, eps 0.10
# 5848581: done 2737 games, mean reward 16.570, speed 111.97 f/s, eps 0.10
# 5851236: done 2738 games, mean reward 16.920, speed 113.72 f/s, eps 0.10
# 5852498: done 2739 games, mean reward 16.960, speed 117.86 f/s, eps 0.10
# 5852679: done 2740 games, mean reward 16.650, speed 105.95 f/s, eps 0.10
# 5853279: done 2741 games, mean reward 16.590, speed 105.89 f/s, eps 0.10
# 5853753: done 2742 games, mean reward 16.400, speed 117.65 f/s, eps 0.10
# 5853996: done 2743 games, mean reward 16.230, speed 117.37 f/s, eps 0.10
# 5854846: done 2744 games, mean reward 16.220, speed 116.82 f/s, eps 0.10
# 5855615: done 2745 games, mean reward 16.130, speed 110.31 f/s, eps 0.10
# 5856674: done 2746 games, mean reward 16.220, speed 115.34 f/s, eps 0.10
# 5858129: done 2747 games, mean reward 16.420, speed 114.31 f/s, eps 0.10
# 5858842: done 2748 games, mean reward 16.340, speed 110.19 f/s, eps 0.10
# 5860143: done 2749 games, mean reward 16.380, speed 112.03 f/s, eps 0.10
# 5860966: done 2750 games, mean reward 16.420, speed 110.69 f/s, eps 0.10
# 5862118: done 2751 games, mean reward 16.340, speed 119.68 f/s, eps 0.10
# 5863605: done 2752 games, mean reward 16.520, speed 111.10 f/s, eps 0.10
# 5864908: done 2753 games, mean reward 16.650, speed 104.94 f/s, eps 0.10
# 5867177: done 2754 games, mean reward 16.620, speed 114.34 f/s, eps 0.10
# 5867463: done 2755 games, mean reward 16.560, speed 99.93 f/s, eps 0.10
# 5867842: done 2756 games, mean reward 16.600, speed 108.76 f/s, eps 0.10
# 5868099: done 2757 games, mean reward 16.020, speed 117.07 f/s, eps 0.10
# 5869298: done 2758 games, mean reward 16.170, speed 118.03 f/s, eps 0.10
# 5870706: done 2759 games, mean reward 16.350, speed 115.31 f/s, eps 0.10
# 5871385: done 2760 games, mean reward 16.380, speed 119.46 f/s, eps 0.10
# 5872505: done 2761 games, mean reward 16.510, speed 117.00 f/s, eps 0.10
# 5873438: done 2762 games, mean reward 16.510, speed 125.24 f/s, eps 0.10
# 5873674: done 2763 games, mean reward 15.960, speed 103.15 f/s, eps 0.10
# 5874959: done 2764 games, mean reward 16.140, speed 114.74 f/s, eps 0.10
# 5876073: done 2765 games, mean reward 16.310, speed 120.25 f/s, eps 0.10
# 5876877: done 2766 games, mean reward 16.100, speed 118.54 f/s, eps 0.10
# 5877385: done 2767 games, mean reward 16.000, speed 109.13 f/s, eps 0.10
# 5877986: done 2768 games, mean reward 15.910, speed 107.95 f/s, eps 0.10
# 5879298: done 2769 games, mean reward 15.990, speed 116.16 f/s, eps 0.10
# 5879546: done 2770 games, mean reward 15.740, speed 103.63 f/s, eps 0.10
# 5881800: done 2771 games, mean reward 15.990, speed 111.61 f/s, eps 0.10
# 5882107: done 2772 games, mean reward 15.470, speed 107.63 f/s, eps 0.10
# 5883836: done 2773 games, mean reward 15.770, speed 151.39 f/s, eps 0.10
# 5884368: done 2774 games, mean reward 15.760, speed 157.82 f/s, eps 0.10
# 5886677: done 2775 games, mean reward 16.010, speed 166.58 f/s, eps 0.10
# 5887817: done 2776 games, mean reward 16.060, speed 161.57 f/s, eps 0.10
# 5889779: done 2777 games, mean reward 16.350, speed 169.48 f/s, eps 0.10
# 5890021: done 2778 games, mean reward 16.230, speed 165.69 f/s, eps 0.10
# 5890425: done 2779 games, mean reward 16.230, speed 173.29 f/s, eps 0.10
# 5892718: done 2780 games, mean reward 16.470, speed 173.03 f/s, eps 0.10
# 5893079: done 2781 games, mean reward 16.450, speed 172.36 f/s, eps 0.10
# 5894260: done 2782 games, mean reward 16.500, speed 171.28 f/s, eps 0.10
# 5895128: done 2783 games, mean reward 16.580, speed 161.15 f/s, eps 0.10
# 5895873: done 2784 games, mean reward 16.260, speed 169.17 f/s, eps 0.10
# 5897149: done 2785 games, mean reward 16.380, speed 173.37 f/s, eps 0.10
# 5899000: done 2786 games, mean reward 16.470, speed 169.15 f/s, eps 0.10
# 5899482: done 2787 games, mean reward 16.330, speed 164.63 f/s, eps 0.10
# 5899969: done 2788 games, mean reward 16.270, speed 170.34 f/s, eps 0.10
# 5900816: done 2789 games, mean reward 16.110, speed 168.15 f/s, eps 0.10
# 5903594: done 2790 games, mean reward 16.220, speed 169.65 f/s, eps 0.10
# 5904232: done 2791 games, mean reward 16.000, speed 160.25 f/s, eps 0.10
# 5905968: done 2792 games, mean reward 16.160, speed 165.10 f/s, eps 0.10
# 5906598: done 2793 games, mean reward 16.110, speed 159.07 f/s, eps 0.10
# 5908408: done 2794 games, mean reward 16.390, speed 169.41 f/s, eps 0.10
# 5909037: done 2795 games, mean reward 16.370, speed 170.17 f/s, eps 0.10
# 5909278: done 2796 games, mean reward 16.230, speed 171.06 f/s, eps 0.10
# 5909702: done 2797 games, mean reward 16.160, speed 164.64 f/s, eps 0.10
# 5910250: done 2798 games, mean reward 15.910, speed 162.64 f/s, eps 0.10
# 5910786: done 2799 games, mean reward 15.860, speed 159.52 f/s, eps 0.10
# 5911024: done 2800 games, mean reward 15.840, speed 152.09 f/s, eps 0.10
# 5911814: done 2801 games, mean reward 15.660, speed 160.05 f/s, eps 0.10
# 5914301: done 2802 games, mean reward 16.000, speed 165.98 f/s, eps 0.10
# 5915234: done 2803 games, mean reward 15.600, speed 165.05 f/s, eps 0.10
# 5916175: done 2804 games, mean reward 15.740, speed 172.87 f/s, eps 0.10
# 5916466: done 2805 games, mean reward 15.610, speed 174.06 f/s, eps 0.10
# 5917644: done 2806 games, mean reward 15.600, speed 171.88 f/s, eps 0.10
# 5919928: done 2807 games, mean reward 15.800, speed 160.31 f/s, eps 0.10
# 5920462: done 2808 games, mean reward 15.650, speed 169.34 f/s, eps 0.10
# 5921134: done 2809 games, mean reward 15.430, speed 173.80 f/s, eps 0.10
# 5923105: done 2810 games, mean reward 15.710, speed 159.37 f/s, eps 0.10
# 5924849: done 2811 games, mean reward 15.600, speed 167.30 f/s, eps 0.10
# 5925067: done 2812 games, mean reward 15.470, speed 164.14 f/s, eps 0.10
# 5928605: done 2813 games, mean reward 15.910, speed 172.57 f/s, eps 0.10
# 5928883: done 2814 games, mean reward 15.850, speed 180.61 f/s, eps 0.10
# 5929081: done 2815 games, mean reward 15.690, speed 160.29 f/s, eps 0.10
# 5931862: done 2816 games, mean reward 15.850, speed 170.18 f/s, eps 0.10
# 5932435: done 2817 games, mean reward 15.520, speed 177.31 f/s, eps 0.10
# 5933286: done 2818 games, mean reward 15.430, speed 163.12 f/s, eps 0.10
# 5934933: done 2819 games, mean reward 15.650, speed 167.69 f/s, eps 0.10
# 5935569: done 2820 games, mean reward 15.410, speed 175.57 f/s, eps 0.10
# 5936053: done 2821 games, mean reward 15.450, speed 166.57 f/s, eps 0.10
# 5936753: done 2822 games, mean reward 15.480, speed 173.01 f/s, eps 0.10
# 5939866: done 2823 games, mean reward 15.650, speed 175.43 f/s, eps 0.10
# 5940282: done 2824 games, mean reward 15.530, speed 161.20 f/s, eps 0.10
# 5941163: done 2825 games, mean reward 15.640, speed 168.86 f/s, eps 0.10
# 5942171: done 2826 games, mean reward 15.670, speed 169.06 f/s, eps 0.10
# 5943788: done 2827 games, mean reward 15.760, speed 174.00 f/s, eps 0.10
# 5946880: done 2828 games, mean reward 16.110, speed 168.14 f/s, eps 0.10
# 5947865: done 2829 games, mean reward 15.960, speed 173.73 f/s, eps 0.10
# 5948651: done 2830 games, mean reward 15.900, speed 174.39 f/s, eps 0.10
# 5949766: done 2831 games, mean reward 15.920, speed 171.69 f/s, eps 0.10
# 5950146: done 2832 games, mean reward 15.840, speed 157.94 f/s, eps 0.10
# 5950478: done 2833 games, mean reward 15.860, speed 164.82 f/s, eps 0.10
# 5952634: done 2834 games, mean reward 16.110, speed 171.81 f/s, eps 0.10
# 5953113: done 2835 games, mean reward 16.070, speed 167.08 f/s, eps 0.10
# 5954044: done 2836 games, mean reward 16.190, speed 172.51 f/s, eps 0.10
# 5955378: done 2837 games, mean reward 16.380, speed 175.07 f/s, eps 0.10
# 5955994: done 2838 games, mean reward 16.030, speed 172.19 f/s, eps 0.10
# 5958501: done 2839 games, mean reward 16.260, speed 166.62 f/s, eps 0.10
# 5958967: done 2840 games, mean reward 16.320, speed 170.45 f/s, eps 0.10
# 5960361: done 2841 games, mean reward 16.380, speed 173.27 f/s, eps 0.10
# 5960581: done 2842 games, mean reward 16.330, speed 155.51 f/s, eps 0.10
# 5963044: done 2843 games, mean reward 16.720, speed 171.77 f/s, eps 0.10
# 5963295: done 2844 games, mean reward 16.590, speed 155.21 f/s, eps 0.10
# 5963668: done 2845 games, mean reward 16.480, speed 159.38 f/s, eps 0.10
# 5964429: done 2846 games, mean reward 16.520, speed 163.40 f/s, eps 0.10
# 5965048: done 2847 games, mean reward 16.410, speed 165.68 f/s, eps 0.10
# 5965316: done 2848 games, mean reward 16.360, speed 149.69 f/s, eps 0.10
# 5965762: done 2849 games, mean reward 16.250, speed 169.39 f/s, eps 0.10
# 5967164: done 2850 games, mean reward 16.310, speed 168.82 f/s, eps 0.10
# 5968419: done 2851 games, mean reward 16.330, speed 166.74 f/s, eps 0.10
# 5969247: done 2852 games, mean reward 16.200, speed 174.17 f/s, eps 0.10
# 5970217: done 2853 games, mean reward 16.160, speed 162.55 f/s, eps 0.10
# 5971097: done 2854 games, mean reward 15.910, speed 161.20 f/s, eps 0.10
# 5972379: done 2855 games, mean reward 16.040, speed 165.01 f/s, eps 0.10
# 5975122: done 2856 games, mean reward 16.290, speed 171.89 f/s, eps 0.10
# 5975735: done 2857 games, mean reward 16.380, speed 163.69 f/s, eps 0.10
# 5977199: done 2858 games, mean reward 16.430, speed 170.18 f/s, eps 0.10
# 5978564: done 2859 games, mean reward 16.330, speed 168.76 f/s, eps 0.10
# 5979206: done 2860 games, mean reward 16.300, speed 162.16 f/s, eps 0.10
# 5980937: done 2861 games, mean reward 16.410, speed 168.45 f/s, eps 0.10
# 5981728: done 2862 games, mean reward 16.410, speed 168.36 f/s, eps 0.10
# 5982275: done 2863 games, mean reward 16.490, speed 173.99 f/s, eps 0.10
# 5983046: done 2864 games, mean reward 16.440, speed 161.28 f/s, eps 0.10
# 5983350: done 2865 games, mean reward 16.300, speed 155.93 f/s, eps 0.10
# 5984025: done 2866 games, mean reward 16.280, speed 165.06 f/s, eps 0.10
# 5984518: done 2867 games, mean reward 16.350, speed 173.84 f/s, eps 0.10
# 5985005: done 2868 games, mean reward 16.340, speed 163.05 f/s, eps 0.10
# 5985263: done 2869 games, mean reward 16.130, speed 171.46 f/s, eps 0.10
# 5986389: done 2870 games, mean reward 16.280, speed 166.35 f/s, eps 0.10
# 5986940: done 2871 games, mean reward 16.030, speed 164.98 f/s, eps 0.10
# 5987163: done 2872 games, mean reward 16.010, speed 163.74 f/s, eps 0.10
# 5989782: done 2873 games, mean reward 16.090, speed 165.67 f/s, eps 0.10
# 5990044: done 2874 games, mean reward 16.060, speed 159.15 f/s, eps 0.10
# 5990686: done 2875 games, mean reward 15.810, speed 168.06 f/s, eps 0.10
# 5991939: done 2876 games, mean reward 15.810, speed 174.01 f/s, eps 0.10
# 5992640: done 2877 games, mean reward 15.610, speed 172.04 f/s, eps 0.10
# 5993606: done 2878 games, mean reward 15.710, speed 172.19 f/s, eps 0.10
# 5995450: done 2879 games, mean reward 15.960, speed 166.10 f/s, eps 0.10
# 5995967: done 2880 games, mean reward 15.700, speed 166.29 f/s, eps 0.10
# 5996419: done 2881 games, mean reward 15.710, speed 168.24 f/s, eps 0.10
# 5997641: done 2882 games, mean reward 15.770, speed 162.21 f/s, eps 0.10
# 5997817: done 2883 games, mean reward 15.620, speed 160.92 f/s, eps 0.10
# 5998423: done 2884 games, mean reward 15.570, speed 159.25 f/s, eps 0.10
# 5999321: done 2885 games, mean reward 15.540, speed 166.67 f/s, eps 0.10

# %%
import os.path
cur_folder = os.getcwd()
model_folder = os.path.join(cur_folder,"models")
if not os.path.exists(model_folder):
    os.makedirs(model_folder)

model_file = os.path.join(model_folder, (tag + ".pt"))
torch.save(net.state_dict(), model_file)
