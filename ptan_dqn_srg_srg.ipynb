# %%
# Training DQN using PTAN library

import warnings
warnings.filterwarnings('ignore',category=FutureWarning) 
# suppress numpy future warnings 
# warning created due to issues with tensorflow 1.14


import gym
import ptan
import argparse

import torch
import torch.optim as optim

from torch.utils.tensorboard import SummaryWriter

from lib import dqn_model, common


import os
import random
import numpy as np

# %%
# parser = argparse.ArgumentParser()
# parser.add_argument("--cuda", default=False, action="store_true", help="Enable GPU [default:False]")
# parser.add_argument("--seed", type=int, help="Set seed [default: 42]")
# parser.add_argument("experiment", help="Experiment to run. Specified in ./lib/common.py")



# args = parser.parse_args()

# %%
# set device
USE_GPU = True#args.cuda
USE_CUDA = torch.cuda.is_available() and USE_GPU
device = torch.device("cuda:0" if USE_CUDA else "cpu")
print("DEVICE #", device, ": ", torch.cuda.get_device_name(device))

# %%
# set seed
seed = 953419#args.seed if args.seed else 42
random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

experiment = "beamrider-v1"#args.experiment
params = common.HYPERPARAMS[experiment]

# %%
env = gym.make(params['env_name'])
env = ptan.common.wrappers.wrap_dqn(env)

tag = params['run_name'] + "-basic-srg" + '-'+ str(seed)
writer = SummaryWriter(comment="-"+ tag)

# %%
net = dqn_model.DQN_A(env.observation_space.shape, 
                    env.action_space.n).to(device)

tgt_net = ptan.agent.TargetNet(net)

# %%
selector = ptan.actions.EpsilonGreedyActionSelector(epsilon=params['epsilon_start'])
epsilon_tracker = common.EpsilonTracker(selector, params)
# epsilon_tracker has only one method frame(frame_idx) which changes the epsilon value 
# of selector=>ptan.actions.EpsilonGreedyActionSelector depending upon the frame

# %%
class DQNAgent_srg(ptan.agent.BaseAgent):
    """
    DQNAgent is a memoryless DQN agent which calculates Q values
    from the observations and  converts them into the actions using action_selector
    """
    def __init__(self, dqn_model, action_selector, device="cpu", preprocessor=ptan.agent.default_states_preprocessor):
        self.dqn_model = dqn_model
        self.action_selector = action_selector
        self.preprocessor = preprocessor
        self.device = device

    @torch.no_grad()
    def __call__(self, states, agent_states=None):
        if agent_states is None:
            agent_states = [None] * len(states)
        if self.preprocessor is not None:
            states = self.preprocessor(states)
            if torch.is_tensor(states):
                states = states.to(self.device)
        q_v, _ = self.dqn_model(states)
        q = q_v.data.cpu().numpy()
        actions = self.action_selector(q)
        return actions, agent_states

# %%
agent = DQNAgent_srg(net, selector, device=device)

exp_source = ptan.experience.ExperienceSourceFirstLast(env, agent, gamma=params['gamma'], steps_count=1)

buffer = ptan.experience.ExperienceReplayBuffer(exp_source, buffer_size=params['replay_size'])

optimizer = optim.Adam(net.parameters(), lr=params['learning_rate'])

# %%
frame_idx = 3E6
INTERRPUTED_MODEL_FILENAME = './models/beamrider-v0-basic-srg-953419.pt'
net.load_state_dict(torch.load(INTERRPUTED_MODEL_FILENAME))
tgt_net.sync()

# %%
with common.RewardTracker(writer, params['stop_reward']) as reward_tracker: #create a reward tracker object
    while True:
        frame_idx += 1
        # ExperienceReplayBuffer asks the ExperienceSourceFirstLast to iterate by one step to get the next transition
        # ExperienceSourceFirstLast feeds observation to obtain action
        # Agent calculated Q-values through the NN
        # Action selector selects action
        # Action is fed into ExperienceSource to obtain reward and next obs
        # Buffer stores transition in FIFO order
        buffer.populate(1) # iterates ExperienceReplayBuffer by 1 step.
                            # this in turn iterates exp_source [ExperienceSourceFirstLast] by one step
                            # one single experience step
                            # Experience = namedtuple('Experience', ['state', 'action', 'reward', 'done'])
                            
                            # Class ExperienceSource provides us full subtrajectories of given length as the list of (s, a, r, s') objects.
                            # Now it returns single object on every iteration, which is again a namedtuple with the following fields:

                            # state: state which we used to decide on action to make TYPE: numpy
                            # action: action we've done at this step
                            # reward: partial accumulated reward for steps_count (in our case, steps_count=1, so it is equal to immediate reward)
                            # last_state: the state we've got after executing the action. If our episode ends, we have None here

                            # For every trajectory piece it calculates discounted reward and emits only first and last states and action taken in the first state.
        epsilon_tracker.frame(frame_idx)
        

        new_rewards = exp_source.pop_total_rewards() # get rewards from the episodes
        if new_rewards:
            if reward_tracker.reward(new_rewards[0], frame_idx, selector.epsilon):
                break

        if len(buffer) < params['replay_initial']:
            continue

        optimizer.zero_grad()
        batch = buffer.sample(params['batch_size'])
        loss_v, feature_loss, qvalue_loss = common.calc_loss_srg(batch, net, tgt_net.target_model, gamma=params['gamma'], device=device)
        if frame_idx % 1E3 == 0:
            writer.add_scalar("loss", loss_v, frame_idx)
            writer.add_scalar("feature_loss", feature_loss, frame_idx)
            writer.add_scalar("qvalue_loss", qvalue_loss, frame_idx)
        loss_v.backward()
        optimizer.step()

        if frame_idx % params['target_net_sync'] == 0:
            tgt_net.sync()
            
        if frame_idx > 6E6:
            break
# Out:
# 3000521: done 1 games, mean reward 7.000, speed 3228307.21 f/s, eps 0.10
# 3001006: done 2 games, mean reward 7.500, speed 743.09 f/s, eps 0.10
# 3002010: done 3 games, mean reward 10.000, speed 746.66 f/s, eps 0.10
# 3002539: done 4 games, mean reward 9.000, speed 740.36 f/s, eps 0.10
# 3003003: done 5 games, mean reward 8.600, speed 745.83 f/s, eps 0.10
# 3004211: done 6 games, mean reward 9.667, speed 750.26 f/s, eps 0.10
# 3007098: done 7 games, mean reward 13.571, speed 736.20 f/s, eps 0.10
# 3009229: done 8 games, mean reward 16.750, speed 717.65 f/s, eps 0.10
# 3009538: done 9 games, mean reward 15.111, speed 722.03 f/s, eps 0.10
# 3010904: done 10 games, mean reward 16.400, speed 214.89 f/s, eps 0.10
# 3013212: done 11 games, mean reward 17.545, speed 166.16 f/s, eps 0.10
# 3013646: done 12 games, mean reward 16.333, speed 157.79 f/s, eps 0.10
# 3014166: done 13 games, mean reward 15.615, speed 161.04 f/s, eps 0.10
# 3014765: done 14 games, mean reward 15.071, speed 158.51 f/s, eps 0.10
# 3015534: done 15 games, mean reward 15.067, speed 161.52 f/s, eps 0.10
# 3015993: done 16 games, mean reward 14.688, speed 161.39 f/s, eps 0.10
# 3018780: done 17 games, mean reward 16.353, speed 173.57 f/s, eps 0.10
# 3019899: done 18 games, mean reward 16.111, speed 176.45 f/s, eps 0.10
# 3022881: done 19 games, mean reward 17.526, speed 161.35 f/s, eps 0.10
# 3024557: done 20 games, mean reward 18.000, speed 170.25 f/s, eps 0.10
# 3024902: done 21 games, mean reward 17.524, speed 154.96 f/s, eps 0.10
# 3025767: done 22 games, mean reward 17.409, speed 160.40 f/s, eps 0.10
# 3026716: done 23 games, mean reward 17.261, speed 156.72 f/s, eps 0.10
# 3026877: done 24 games, mean reward 16.542, speed 174.58 f/s, eps 0.10
# 3027536: done 25 games, mean reward 16.280, speed 177.43 f/s, eps 0.10
# 3028847: done 26 games, mean reward 16.385, speed 162.64 f/s, eps 0.10
# 3029727: done 27 games, mean reward 16.111, speed 160.12 f/s, eps 0.10
# 3030093: done 28 games, mean reward 15.714, speed 156.07 f/s, eps 0.10
# 3033831: done 29 games, mean reward 17.034, speed 165.79 f/s, eps 0.10
# 3034007: done 30 games, mean reward 16.500, speed 169.28 f/s, eps 0.10
# 3034823: done 31 games, mean reward 16.452, speed 162.09 f/s, eps 0.10
# 3035006: done 32 games, mean reward 15.938, speed 160.95 f/s, eps 0.10
# 3035556: done 33 games, mean reward 15.788, speed 178.05 f/s, eps 0.10
# 3036178: done 34 games, mean reward 15.676, speed 168.43 f/s, eps 0.10
# 3039006: done 35 games, mean reward 16.171, speed 163.22 f/s, eps 0.10
# 3040390: done 36 games, mean reward 16.556, speed 158.77 f/s, eps 0.10
# 3043741: done 37 games, mean reward 17.649, speed 163.75 f/s, eps 0.10
# 3044156: done 38 games, mean reward 17.289, speed 162.82 f/s, eps 0.10
# 3044454: done 39 games, mean reward 16.923, speed 158.99 f/s, eps 0.10
# 3045102: done 40 games, mean reward 16.825, speed 156.04 f/s, eps 0.10
# 3046267: done 41 games, mean reward 16.756, speed 158.12 f/s, eps 0.10
# 3047858: done 42 games, mean reward 16.881, speed 164.04 f/s, eps 0.10
# 3049068: done 43 games, mean reward 16.837, speed 166.87 f/s, eps 0.10
# 3049930: done 44 games, mean reward 16.727, speed 165.22 f/s, eps 0.10
# 3050227: done 45 games, mean reward 16.422, speed 159.01 f/s, eps 0.10
# 3050990: done 46 games, mean reward 16.391, speed 160.07 f/s, eps 0.10
# 3052135: done 47 games, mean reward 16.383, speed 158.73 f/s, eps 0.10
# 3052525: done 48 games, mean reward 16.208, speed 159.14 f/s, eps 0.10
# 3053292: done 49 games, mean reward 16.184, speed 165.58 f/s, eps 0.10
# 3053592: done 50 games, mean reward 15.940, speed 154.16 f/s, eps 0.10
# 3055933: done 51 games, mean reward 16.431, speed 158.49 f/s, eps 0.10
# 3056818: done 52 games, mean reward 16.404, speed 160.41 f/s, eps 0.10
# 3057521: done 53 games, mean reward 16.340, speed 177.81 f/s, eps 0.10
# 3057721: done 54 games, mean reward 16.056, speed 168.77 f/s, eps 0.10
# 3059162: done 55 games, mean reward 16.164, speed 171.68 f/s, eps 0.10
# 3059662: done 56 games, mean reward 15.982, speed 161.55 f/s, eps 0.10
# 3060120: done 57 games, mean reward 15.737, speed 162.52 f/s, eps 0.10
# 3060868: done 58 games, mean reward 15.724, speed 177.57 f/s, eps 0.10
# 3062262: done 59 games, mean reward 15.864, speed 162.34 f/s, eps 0.10
# 3062430: done 60 games, mean reward 15.600, speed 172.99 f/s, eps 0.10
# 3063518: done 61 games, mean reward 15.672, speed 170.07 f/s, eps 0.10
# 3064329: done 62 games, mean reward 15.581, speed 162.07 f/s, eps 0.10
# 3065225: done 63 games, mean reward 15.571, speed 162.98 f/s, eps 0.10
# 3066582: done 64 games, mean reward 15.703, speed 171.31 f/s, eps 0.10
# 3066882: done 65 games, mean reward 15.492, speed 182.19 f/s, eps 0.10
# 3067386: done 66 games, mean reward 15.303, speed 181.25 f/s, eps 0.10
# 3069095: done 67 games, mean reward 15.478, speed 182.41 f/s, eps 0.10
# 3069296: done 68 games, mean reward 15.279, speed 182.43 f/s, eps 0.10
# 3069536: done 69 games, mean reward 15.072, speed 181.58 f/s, eps 0.10
# 3071074: done 70 games, mean reward 15.271, speed 161.13 f/s, eps 0.10
# 3071326: done 71 games, mean reward 15.056, speed 151.67 f/s, eps 0.10
# 3073200: done 72 games, mean reward 15.194, speed 157.11 f/s, eps 0.10
# 3075123: done 73 games, mean reward 15.370, speed 159.68 f/s, eps 0.10
# 3076206: done 74 games, mean reward 15.324, speed 161.18 f/s, eps 0.10
# 3077476: done 75 games, mean reward 15.360, speed 162.50 f/s, eps 0.10
# 3079650: done 76 games, mean reward 15.553, speed 162.80 f/s, eps 0.10
# 3081604: done 77 games, mean reward 15.740, speed 157.26 f/s, eps 0.10
# 3082167: done 78 games, mean reward 15.679, speed 168.99 f/s, eps 0.10
# 3084112: done 79 games, mean reward 15.886, speed 167.38 f/s, eps 0.10
# 3085586: done 80 games, mean reward 16.025, speed 164.79 f/s, eps 0.10
# 3085861: done 81 games, mean reward 15.864, speed 166.36 f/s, eps 0.10
# 3086704: done 82 games, mean reward 15.829, speed 174.88 f/s, eps 0.10
# 3087580: done 83 games, mean reward 15.819, speed 162.29 f/s, eps 0.10
# 3088384: done 84 games, mean reward 15.774, speed 154.58 f/s, eps 0.10
# 3089652: done 85 games, mean reward 15.753, speed 150.17 f/s, eps 0.10
# 3092549: done 86 games, mean reward 16.093, speed 167.69 f/s, eps 0.10
# 3093019: done 87 games, mean reward 16.011, speed 174.31 f/s, eps 0.10
# 3093398: done 88 games, mean reward 15.875, speed 175.30 f/s, eps 0.10
# 3094374: done 89 games, mean reward 15.865, speed 174.78 f/s, eps 0.10
# 3094736: done 90 games, mean reward 15.756, speed 157.69 f/s, eps 0.10
# 3095830: done 91 games, mean reward 15.824, speed 176.73 f/s, eps 0.10
# 3099034: done 92 games, mean reward 16.130, speed 163.59 f/s, eps 0.10
# 3100232: done 93 games, mean reward 16.086, speed 167.05 f/s, eps 0.10
# 3101453: done 94 games, mean reward 16.096, speed 162.15 f/s, eps 0.10
# 3102454: done 95 games, mean reward 16.084, speed 165.76 f/s, eps 0.10
# 3103199: done 96 games, mean reward 16.010, speed 167.92 f/s, eps 0.10
# 3103615: done 97 games, mean reward 15.897, speed 165.53 f/s, eps 0.10
# 3105148: done 98 games, mean reward 16.010, speed 159.21 f/s, eps 0.10
# 3106836: done 99 games, mean reward 16.030, speed 170.75 f/s, eps 0.10
# 3107415: done 100 games, mean reward 15.970, speed 155.30 f/s, eps 0.10
# 3108582: done 101 games, mean reward 16.130, speed 158.62 f/s, eps 0.10
# 3108954: done 102 games, mean reward 16.110, speed 151.47 f/s, eps 0.10
# 3109212: done 103 games, mean reward 15.970, speed 156.82 f/s, eps 0.10
# 3110338: done 104 games, mean reward 16.100, speed 169.28 f/s, eps 0.10
# 3111050: done 105 games, mean reward 16.130, speed 157.29 f/s, eps 0.10
# 3111327: done 106 games, mean reward 15.980, speed 168.60 f/s, eps 0.10
# 3111862: done 107 games, mean reward 15.730, speed 166.30 f/s, eps 0.10
# 3112209: done 108 games, mean reward 15.370, speed 166.71 f/s, eps 0.10
# 3112384: done 109 games, mean reward 15.350, speed 166.75 f/s, eps 0.10
# 3112840: done 110 games, mean reward 15.180, speed 175.57 f/s, eps 0.10
# 3113496: done 111 games, mean reward 14.940, speed 154.98 f/s, eps 0.10
# 3113892: done 112 games, mean reward 14.970, speed 178.53 f/s, eps 0.10
# 3114971: done 113 games, mean reward 15.070, speed 171.90 f/s, eps 0.10
# 3115234: done 114 games, mean reward 15.010, speed 174.64 f/s, eps 0.10
# 3115830: done 115 games, mean reward 14.940, speed 160.33 f/s, eps 0.10
# 3118052: done 116 games, mean reward 15.250, speed 158.59 f/s, eps 0.10
# 3118856: done 117 games, mean reward 14.980, speed 167.04 f/s, eps 0.10
# 3119599: done 118 games, mean reward 15.000, speed 147.50 f/s, eps 0.10
# 3120425: done 119 games, mean reward 14.710, speed 128.14 f/s, eps 0.10
# 3123157: done 120 games, mean reward 14.840, speed 120.59 f/s, eps 0.10
# 3123649: done 121 games, mean reward 14.810, speed 120.19 f/s, eps 0.10
# 3126134: done 122 games, mean reward 15.060, speed 112.87 f/s, eps 0.10
# 3126553: done 123 games, mean reward 14.950, speed 128.07 f/s, eps 0.10
# 3126908: done 124 games, mean reward 14.960, speed 131.06 f/s, eps 0.10
# 3127332: done 125 games, mean reward 14.930, speed 133.11 f/s, eps 0.10
# 3129809: done 126 games, mean reward 14.960, speed 124.09 f/s, eps 0.10
# 3131046: done 127 games, mean reward 15.030, speed 131.19 f/s, eps 0.10
# 3133007: done 128 games, mean reward 15.280, speed 125.18 f/s, eps 0.10
# 3133826: done 129 games, mean reward 14.860, speed 124.29 f/s, eps 0.10
# 3134869: done 130 games, mean reward 14.980, speed 123.64 f/s, eps 0.10
# 3136462: done 131 games, mean reward 15.130, speed 126.11 f/s, eps 0.10
# 3137290: done 132 games, mean reward 15.280, speed 129.24 f/s, eps 0.10
# 3138087: done 133 games, mean reward 15.310, speed 128.10 f/s, eps 0.10
# 3139604: done 134 games, mean reward 15.400, speed 125.00 f/s, eps 0.10
# 3139895: done 135 games, mean reward 15.090, speed 125.01 f/s, eps 0.10
# 3140666: done 136 games, mean reward 14.860, speed 126.71 f/s, eps 0.10
# 3141433: done 137 games, mean reward 14.440, speed 127.69 f/s, eps 0.10
# 3144224: done 138 games, mean reward 14.780, speed 127.46 f/s, eps 0.10
# 3144387: done 139 games, mean reward 14.760, speed 120.70 f/s, eps 0.10
# 3145337: done 140 games, mean reward 14.780, speed 128.49 f/s, eps 0.10
# 3145879: done 141 games, mean reward 14.740, speed 132.74 f/s, eps 0.10
# 3146674: done 142 games, mean reward 14.590, speed 131.80 f/s, eps 0.10
# 3147092: done 143 games, mean reward 14.520, speed 131.42 f/s, eps 0.10
# 3148742: done 144 games, mean reward 14.590, speed 128.32 f/s, eps 0.10
# 3149350: done 145 games, mean reward 14.590, speed 130.56 f/s, eps 0.10
# 3150477: done 146 games, mean reward 14.640, speed 127.35 f/s, eps 0.10
# 3153146: done 147 games, mean reward 14.880, speed 127.67 f/s, eps 0.10
# 3153578: done 148 games, mean reward 14.860, speed 128.15 f/s, eps 0.10
# 3157424: done 149 games, mean reward 15.320, speed 128.17 f/s, eps 0.10
# 3158244: done 150 games, mean reward 15.420, speed 127.86 f/s, eps 0.10
# 3159012: done 151 games, mean reward 15.130, speed 119.85 f/s, eps 0.10
# 3159431: done 152 games, mean reward 15.040, speed 125.70 f/s, eps 0.10
# 3161787: done 153 games, mean reward 15.300, speed 126.28 f/s, eps 0.10
# 3162300: done 154 games, mean reward 15.400, speed 127.15 f/s, eps 0.10
# 3162806: done 155 games, mean reward 15.270, speed 114.99 f/s, eps 0.10
# 3164677: done 156 games, mean reward 15.450, speed 122.85 f/s, eps 0.10
# 3165215: done 157 games, mean reward 15.490, speed 129.54 f/s, eps 0.10
# 3167131: done 158 games, mean reward 15.650, speed 127.14 f/s, eps 0.10
# 3168049: done 159 games, mean reward 15.550, speed 127.48 f/s, eps 0.10
# 3168683: done 160 games, mean reward 15.630, speed 127.97 f/s, eps 0.10
# 3169421: done 161 games, mean reward 15.580, speed 127.08 f/s, eps 0.10
# 3170789: done 162 games, mean reward 15.740, speed 127.33 f/s, eps 0.10
# 3171091: done 163 games, mean reward 15.600, speed 123.77 f/s, eps 0.10
# 3173149: done 164 games, mean reward 15.660, speed 127.05 f/s, eps 0.10
# 3173720: done 165 games, mean reward 15.740, speed 123.27 f/s, eps 0.10
# 3174944: done 166 games, mean reward 15.920, speed 123.46 f/s, eps 0.10
# 3176569: done 167 games, mean reward 15.950, speed 130.32 f/s, eps 0.10
# 3176736: done 168 games, mean reward 15.930, speed 126.42 f/s, eps 0.10
# 3178820: done 169 games, mean reward 16.270, speed 126.55 f/s, eps 0.10
# 3180755: done 170 games, mean reward 16.260, speed 125.53 f/s, eps 0.10
# 3182077: done 171 games, mean reward 16.400, speed 125.22 f/s, eps 0.10
# 3182886: done 172 games, mean reward 16.280, speed 125.99 f/s, eps 0.10
# 3184376: done 173 games, mean reward 16.300, speed 125.78 f/s, eps 0.10
# 3184712: done 174 games, mean reward 16.240, speed 128.02 f/s, eps 0.10
# 3186000: done 175 games, mean reward 16.270, speed 123.33 f/s, eps 0.10
# 3186870: done 176 games, mean reward 16.120, speed 126.37 f/s, eps 0.10
# 3187447: done 177 games, mean reward 15.910, speed 126.61 f/s, eps 0.10
# 3188889: done 178 games, mean reward 16.000, speed 126.68 f/s, eps 0.10
# 3190242: done 179 games, mean reward 15.890, speed 125.62 f/s, eps 0.10
# 3191311: done 180 games, mean reward 15.800, speed 128.28 f/s, eps 0.10
# 3193098: done 181 games, mean reward 16.110, speed 126.90 f/s, eps 0.10
# 3193890: done 182 games, mean reward 16.130, speed 130.08 f/s, eps 0.10
# 3194123: done 183 games, mean reward 16.010, speed 122.93 f/s, eps 0.10
# 3194719: done 184 games, mean reward 15.980, speed 129.19 f/s, eps 0.10
# 3196788: done 185 games, mean reward 16.180, speed 127.28 f/s, eps 0.10
# 3197103: done 186 games, mean reward 15.760, speed 125.93 f/s, eps 0.10
# 3198387: done 187 games, mean reward 15.880, speed 130.28 f/s, eps 0.10
# 3200935: done 188 games, mean reward 16.260, speed 128.41 f/s, eps 0.10
# 3201531: done 189 games, mean reward 16.130, speed 129.27 f/s, eps 0.10
# 3203328: done 190 games, mean reward 16.350, speed 129.48 f/s, eps 0.10
# 3204086: done 191 games, mean reward 16.280, speed 127.67 f/s, eps 0.10
# 3204848: done 192 games, mean reward 15.980, speed 129.23 f/s, eps 0.10
# 3205993: done 193 games, mean reward 15.960, speed 129.79 f/s, eps 0.10
# 3207466: done 194 games, mean reward 16.020, speed 126.26 f/s, eps 0.10
# 3209384: done 195 games, mean reward 16.190, speed 126.68 f/s, eps 0.10
# 3209793: done 196 games, mean reward 16.150, speed 108.54 f/s, eps 0.10
# 3210557: done 197 games, mean reward 16.250, speed 110.89 f/s, eps 0.10
# 3211529: done 198 games, mean reward 16.120, speed 110.23 f/s, eps 0.10
# 3212679: done 199 games, mean reward 16.100, speed 121.83 f/s, eps 0.10
# 3214215: done 200 games, mean reward 16.240, speed 126.45 f/s, eps 0.10
# 3214873: done 201 games, mean reward 16.070, speed 123.62 f/s, eps 0.10
# 3215577: done 202 games, mean reward 16.160, speed 127.18 f/s, eps 0.10
# 3217912: done 203 games, mean reward 16.600, speed 126.58 f/s, eps 0.10
# 3218808: done 204 games, mean reward 16.550, speed 131.25 f/s, eps 0.10
# 3219745: done 205 games, mean reward 16.600, speed 125.80 f/s, eps 0.10
# 3221895: done 206 games, mean reward 16.890, speed 127.03 f/s, eps 0.10
# 3222343: done 207 games, mean reward 16.790, speed 130.51 f/s, eps 0.10
# 3224107: done 208 games, mean reward 17.030, speed 127.81 f/s, eps 0.10
# 3227329: done 209 games, mean reward 17.560, speed 119.52 f/s, eps 0.10
# 3227659: done 210 games, mean reward 17.490, speed 126.53 f/s, eps 0.10
# 3228125: done 211 games, mean reward 17.470, speed 127.37 f/s, eps 0.10
# 3229568: done 212 games, mean reward 17.620, speed 128.24 f/s, eps 0.10
# 3229886: done 213 games, mean reward 17.470, speed 129.90 f/s, eps 0.10
# 3231733: done 214 games, mean reward 17.720, speed 126.83 f/s, eps 0.10
# 3233157: done 215 games, mean reward 17.920, speed 126.43 f/s, eps 0.10
# 3233556: done 216 games, mean reward 17.540, speed 128.68 f/s, eps 0.10
# 3235621: done 217 games, mean reward 17.690, speed 125.94 f/s, eps 0.10
# 3236126: done 218 games, mean reward 17.570, speed 123.38 f/s, eps 0.10
# 3237115: done 219 games, mean reward 17.580, speed 127.63 f/s, eps 0.10
# 3237909: done 220 games, mean reward 17.310, speed 127.63 f/s, eps 0.10
# 3238164: done 221 games, mean reward 17.280, speed 130.22 f/s, eps 0.10
# 3239339: done 222 games, mean reward 17.100, speed 126.23 f/s, eps 0.10
# 3241511: done 223 games, mean reward 17.390, speed 125.63 f/s, eps 0.10
# 3241771: done 224 games, mean reward 17.400, speed 128.67 f/s, eps 0.10
# 3243235: done 225 games, mean reward 17.590, speed 125.71 f/s, eps 0.10
# 3243632: done 226 games, mean reward 17.400, speed 126.56 f/s, eps 0.10
# 3244344: done 227 games, mean reward 17.300, speed 122.87 f/s, eps 0.10
# 3245522: done 228 games, mean reward 17.150, speed 125.58 f/s, eps 0.10
# 3246123: done 229 games, mean reward 17.120, speed 124.29 f/s, eps 0.10
# 3246512: done 230 games, mean reward 17.030, speed 123.62 f/s, eps 0.10
# 3248156: done 231 games, mean reward 17.000, speed 124.80 f/s, eps 0.10
# 3248460: done 232 games, mean reward 16.870, speed 123.15 f/s, eps 0.10
# 3248671: done 233 games, mean reward 16.740, speed 124.56 f/s, eps 0.10
# 3250207: done 234 games, mean reward 16.820, speed 124.24 f/s, eps 0.10
# 3251096: done 235 games, mean reward 16.910, speed 123.01 f/s, eps 0.10
# 3251386: done 236 games, mean reward 16.850, speed 125.48 f/s, eps 0.10
# 3252617: done 237 games, mean reward 16.930, speed 126.14 f/s, eps 0.10
# 3253016: done 238 games, mean reward 16.600, speed 123.33 f/s, eps 0.10
# 3254213: done 239 games, mean reward 16.710, speed 123.93 f/s, eps 0.10
# 3257639: done 240 games, mean reward 17.100, speed 126.14 f/s, eps 0.10
# 3259931: done 241 games, mean reward 17.330, speed 127.89 f/s, eps 0.10
# 3260209: done 242 games, mean reward 17.280, speed 128.91 f/s, eps 0.10
# 3261709: done 243 games, mean reward 17.430, speed 125.37 f/s, eps 0.10
# 3262243: done 244 games, mean reward 17.300, speed 127.55 f/s, eps 0.10
# 3262835: done 245 games, mean reward 17.310, speed 126.43 f/s, eps 0.10
# 3266331: done 246 games, mean reward 17.700, speed 121.48 f/s, eps 0.10
# 3267002: done 247 games, mean reward 17.390, speed 111.32 f/s, eps 0.10
# 3267414: done 248 games, mean reward 17.410, speed 110.81 f/s, eps 0.10
# 3268259: done 249 games, mean reward 16.950, speed 108.08 f/s, eps 0.10
# 3269318: done 250 games, mean reward 16.970, speed 109.13 f/s, eps 0.10
# 3269562: done 251 games, mean reward 16.870, speed 105.86 f/s, eps 0.10
# 3270511: done 252 games, mean reward 16.960, speed 107.04 f/s, eps 0.10
# 3271438: done 253 games, mean reward 16.740, speed 113.97 f/s, eps 0.10
# 3272057: done 254 games, mean reward 16.700, speed 125.21 f/s, eps 0.10
# 3272474: done 255 games, mean reward 16.670, speed 126.00 f/s, eps 0.10
# 3273690: done 256 games, mean reward 16.580, speed 128.18 f/s, eps 0.10
# 3274099: done 257 games, mean reward 16.580, speed 128.45 f/s, eps 0.10
# 3275348: done 258 games, mean reward 16.470, speed 125.71 f/s, eps 0.10
# 3275993: done 259 games, mean reward 16.430, speed 127.76 f/s, eps 0.10
# 3276932: done 260 games, mean reward 16.510, speed 126.81 f/s, eps 0.10
# 3277352: done 261 games, mean reward 16.450, speed 123.89 f/s, eps 0.10
# 3277912: done 262 games, mean reward 16.250, speed 125.72 f/s, eps 0.10
# 3279311: done 263 games, mean reward 16.480, speed 125.86 f/s, eps 0.10
# 3280069: done 264 games, mean reward 16.330, speed 125.35 f/s, eps 0.10
# 3280495: done 265 games, mean reward 16.310, speed 128.65 f/s, eps 0.10
# 3280789: done 266 games, mean reward 16.120, speed 128.28 f/s, eps 0.10
# 3282778: done 267 games, mean reward 16.200, speed 126.45 f/s, eps 0.10
# 3283190: done 268 games, mean reward 16.260, speed 126.07 f/s, eps 0.10
# 3284309: done 269 games, mean reward 16.040, speed 123.68 f/s, eps 0.10
# 3285954: done 270 games, mean reward 16.080, speed 126.45 f/s, eps 0.10
# 3286113: done 271 games, mean reward 15.940, speed 119.43 f/s, eps 0.10
# 3286598: done 272 games, mean reward 15.860, speed 126.37 f/s, eps 0.10
# 3287048: done 273 games, mean reward 15.650, speed 127.52 f/s, eps 0.10
# 3288299: done 274 games, mean reward 15.770, speed 126.76 f/s, eps 0.10
# 3289743: done 275 games, mean reward 15.720, speed 127.24 f/s, eps 0.10
# 3292146: done 276 games, mean reward 15.880, speed 125.48 f/s, eps 0.10
# 3292856: done 277 games, mean reward 15.920, speed 124.19 f/s, eps 0.10
# 3293891: done 278 games, mean reward 15.880, speed 127.98 f/s, eps 0.10
# 3294871: done 279 games, mean reward 15.820, speed 123.81 f/s, eps 0.10
# 3295496: done 280 games, mean reward 15.740, speed 124.06 f/s, eps 0.10
# 3296351: done 281 games, mean reward 15.490, speed 126.07 f/s, eps 0.10
# 3297040: done 282 games, mean reward 15.490, speed 127.99 f/s, eps 0.10
# 3299205: done 283 games, mean reward 15.860, speed 126.85 f/s, eps 0.10
# 3299453: done 284 games, mean reward 15.800, speed 123.51 f/s, eps 0.10
# 3300529: done 285 games, mean reward 15.620, speed 128.09 f/s, eps 0.10
# 3300886: done 286 games, mean reward 15.650, speed 130.83 f/s, eps 0.10
# 3301140: done 287 games, mean reward 15.460, speed 128.56 f/s, eps 0.10
# 3302789: done 288 games, mean reward 15.250, speed 126.89 f/s, eps 0.10
# 3303626: done 289 games, mean reward 15.360, speed 128.77 f/s, eps 0.10
# 3305732: done 290 games, mean reward 15.450, speed 128.04 f/s, eps 0.10
# 3306457: done 291 games, mean reward 15.450, speed 126.88 f/s, eps 0.10
# 3307194: done 292 games, mean reward 15.450, speed 129.24 f/s, eps 0.10
# 3308085: done 293 games, mean reward 15.510, speed 126.46 f/s, eps 0.10
# 3308900: done 294 games, mean reward 15.430, speed 126.06 f/s, eps 0.10
# 3309311: done 295 games, mean reward 15.190, speed 127.63 f/s, eps 0.10
# 3309672: done 296 games, mean reward 15.200, speed 119.78 f/s, eps 0.10
# 3310229: done 297 games, mean reward 15.160, speed 110.47 f/s, eps 0.10
# 3312512: done 298 games, mean reward 15.380, speed 110.63 f/s, eps 0.10
# 3313023: done 299 games, mean reward 15.340, speed 108.69 f/s, eps 0.10
# 3314969: done 300 games, mean reward 15.390, speed 122.31 f/s, eps 0.10
# 3315196: done 301 games, mean reward 15.340, speed 128.99 f/s, eps 0.10
# 3315414: done 302 games, mean reward 15.190, speed 123.60 f/s, eps 0.10
# 3316840: done 303 games, mean reward 14.980, speed 127.55 f/s, eps 0.10
# 3317489: done 304 games, mean reward 14.900, speed 124.39 f/s, eps 0.10
# 3318350: done 305 games, mean reward 14.880, speed 127.56 f/s, eps 0.10
# 3319818: done 306 games, mean reward 14.860, speed 129.03 f/s, eps 0.10
# 3320104: done 307 games, mean reward 14.870, speed 122.70 f/s, eps 0.10
# 3320669: done 308 games, mean reward 14.710, speed 125.29 f/s, eps 0.10
# 3321156: done 309 games, mean reward 14.260, speed 127.40 f/s, eps 0.10
# 3321775: done 310 games, mean reward 14.280, speed 126.59 f/s, eps 0.10
# 3324336: done 311 games, mean reward 14.560, speed 126.70 f/s, eps 0.10
# 3325086: done 312 games, mean reward 14.500, speed 128.32 f/s, eps 0.10
# 3325903: done 313 games, mean reward 14.610, speed 127.23 f/s, eps 0.10
# 3327105: done 314 games, mean reward 14.480, speed 128.03 f/s, eps 0.10
# 3328431: done 315 games, mean reward 14.420, speed 127.88 f/s, eps 0.10
# 3329388: done 316 games, mean reward 14.490, speed 125.09 f/s, eps 0.10
# 3329821: done 317 games, mean reward 14.230, speed 123.88 f/s, eps 0.10
# 3331426: done 318 games, mean reward 14.450, speed 128.90 f/s, eps 0.10
# 3332057: done 319 games, mean reward 14.360, speed 126.10 f/s, eps 0.10
# 3332610: done 320 games, mean reward 14.320, speed 127.13 f/s, eps 0.10
# 3333505: done 321 games, mean reward 14.440, speed 125.32 f/s, eps 0.10
# 3334275: done 322 games, mean reward 14.300, speed 127.00 f/s, eps 0.10
# 3335653: done 323 games, mean reward 14.210, speed 125.71 f/s, eps 0.10
# 3336648: done 324 games, mean reward 14.340, speed 126.03 f/s, eps 0.10
# 3337531: done 325 games, mean reward 14.230, speed 124.13 f/s, eps 0.10
# 3337707: done 326 games, mean reward 14.210, speed 125.54 f/s, eps 0.10
# 3339170: done 327 games, mean reward 14.410, speed 127.19 f/s, eps 0.10
# 3339641: done 328 games, mean reward 14.290, speed 126.41 f/s, eps 0.10
# 3340641: done 329 games, mean reward 14.310, speed 123.04 f/s, eps 0.10
# 3343280: done 330 games, mean reward 14.700, speed 114.37 f/s, eps 0.10
# 3343582: done 331 games, mean reward 14.450, speed 130.73 f/s, eps 0.10
# 3344271: done 332 games, mean reward 14.550, speed 124.39 f/s, eps 0.10
# 3346446: done 333 games, mean reward 14.940, speed 124.03 f/s, eps 0.10
# 3347923: done 334 games, mean reward 14.850, speed 125.47 f/s, eps 0.10
# 3348287: done 335 games, mean reward 14.800, speed 128.27 f/s, eps 0.10
# 3350635: done 336 games, mean reward 15.100, speed 126.78 f/s, eps 0.10
# 3351428: done 337 games, mean reward 15.000, speed 129.01 f/s, eps 0.10
# 3352572: done 338 games, mean reward 15.080, speed 125.87 f/s, eps 0.10
# 3353745: done 339 games, mean reward 15.110, speed 128.95 f/s, eps 0.10
# 3353926: done 340 games, mean reward 14.570, speed 129.75 f/s, eps 0.10
# 3354387: done 341 games, mean reward 14.330, speed 126.08 f/s, eps 0.10
# 3358399: done 342 games, mean reward 15.060, speed 126.98 f/s, eps 0.10
# 3358897: done 343 games, mean reward 14.870, speed 127.95 f/s, eps 0.10
# 3359463: done 344 games, mean reward 14.950, speed 130.80 f/s, eps 0.10
# 3360224: done 345 games, mean reward 15.060, speed 127.05 f/s, eps 0.10
# 3360730: done 346 games, mean reward 14.570, speed 129.65 f/s, eps 0.10
# 3361086: done 347 games, mean reward 14.530, speed 126.26 f/s, eps 0.10
# 3362568: done 348 games, mean reward 14.730, speed 127.90 f/s, eps 0.10
# 3363453: done 349 games, mean reward 14.680, speed 123.07 f/s, eps 0.10
# 3365719: done 350 games, mean reward 14.870, speed 122.29 f/s, eps 0.10
# 3366123: done 351 games, mean reward 14.930, speed 120.74 f/s, eps 0.10
# 3367724: done 352 games, mean reward 15.030, speed 127.05 f/s, eps 0.10
# 3368488: done 353 games, mean reward 14.980, speed 128.17 f/s, eps 0.10
# 3370335: done 354 games, mean reward 15.180, speed 126.00 f/s, eps 0.10
# 3370885: done 355 games, mean reward 15.150, speed 125.41 f/s, eps 0.10
# 3371088: done 356 games, mean reward 15.010, speed 127.29 f/s, eps 0.10
# 3371603: done 357 games, mean reward 15.010, speed 130.00 f/s, eps 0.10
# 3373794: done 358 games, mean reward 15.260, speed 127.05 f/s, eps 0.10
# 3374987: done 359 games, mean reward 15.340, speed 114.67 f/s, eps 0.10
# 3375593: done 360 games, mean reward 15.310, speed 110.20 f/s, eps 0.10
# 3377003: done 361 games, mean reward 15.490, speed 110.31 f/s, eps 0.10
# 3377165: done 362 games, mean reward 15.430, speed 113.06 f/s, eps 0.10
# 3377338: done 363 games, mean reward 15.190, speed 110.70 f/s, eps 0.10
# 3378354: done 364 games, mean reward 15.240, speed 111.05 f/s, eps 0.10
# 3378842: done 365 games, mean reward 15.210, speed 109.95 f/s, eps 0.10
# 3379285: done 366 games, mean reward 15.240, speed 110.90 f/s, eps 0.10
# 3380249: done 367 games, mean reward 15.000, speed 109.91 f/s, eps 0.10
# 3382885: done 368 games, mean reward 15.390, speed 118.44 f/s, eps 0.10
# 3384397: done 369 games, mean reward 15.450, speed 127.89 f/s, eps 0.10
# 3384834: done 370 games, mean reward 15.210, speed 127.45 f/s, eps 0.10
# 3387024: done 371 games, mean reward 15.510, speed 126.47 f/s, eps 0.10
# 3387347: done 372 games, mean reward 15.520, speed 127.62 f/s, eps 0.10
# 3389073: done 373 games, mean reward 15.730, speed 126.84 f/s, eps 0.10
# 3389718: done 374 games, mean reward 15.620, speed 126.93 f/s, eps 0.10
# 3389957: done 375 games, mean reward 15.490, speed 128.71 f/s, eps 0.10
# 3390546: done 376 games, mean reward 15.260, speed 129.38 f/s, eps 0.10
# 3391990: done 377 games, mean reward 15.340, speed 126.57 f/s, eps 0.10
# 3393248: done 378 games, mean reward 15.320, speed 125.95 f/s, eps 0.10
# 3394453: done 379 games, mean reward 15.380, speed 124.13 f/s, eps 0.10
# 3395653: done 380 games, mean reward 15.430, speed 122.16 f/s, eps 0.10
# 3396868: done 381 games, mean reward 15.490, speed 125.98 f/s, eps 0.10
# 3397555: done 382 games, mean reward 15.480, speed 127.76 f/s, eps 0.10
# 3397830: done 383 games, mean reward 15.090, speed 123.05 f/s, eps 0.10
# 3399114: done 384 games, mean reward 15.270, speed 125.43 f/s, eps 0.10
# 3400440: done 385 games, mean reward 15.360, speed 129.58 f/s, eps 0.10
# 3400835: done 386 games, mean reward 15.330, speed 125.74 f/s, eps 0.10
# 3402315: done 387 games, mean reward 15.500, speed 125.70 f/s, eps 0.10
# 3403138: done 388 games, mean reward 15.440, speed 126.59 f/s, eps 0.10
# 3405116: done 389 games, mean reward 15.530, speed 127.54 f/s, eps 0.10
# 3405798: done 390 games, mean reward 15.240, speed 127.84 f/s, eps 0.10
# 3406291: done 391 games, mean reward 15.170, speed 121.09 f/s, eps 0.10
# 3406655: done 392 games, mean reward 15.080, speed 125.10 f/s, eps 0.10
# 3409507: done 393 games, mean reward 15.350, speed 125.80 f/s, eps 0.10
# 3409958: done 394 games, mean reward 15.260, speed 124.25 f/s, eps 0.10
# 3410514: done 395 games, mean reward 15.270, speed 129.64 f/s, eps 0.10
# 3411639: done 396 games, mean reward 15.360, speed 125.68 f/s, eps 0.10
# 3412286: done 397 games, mean reward 15.400, speed 108.57 f/s, eps 0.10
# 3413850: done 398 games, mean reward 15.320, speed 113.62 f/s, eps 0.10
# 3414032: done 399 games, mean reward 15.200, speed 106.98 f/s, eps 0.10
# 3415875: done 400 games, mean reward 15.210, speed 118.56 f/s, eps 0.10
# 3416407: done 401 games, mean reward 15.300, speed 100.70 f/s, eps 0.10
# 3417614: done 402 games, mean reward 15.480, speed 99.53 f/s, eps 0.10
# 3418634: done 403 games, mean reward 15.390, speed 96.39 f/s, eps 0.10
# 3419030: done 404 games, mean reward 15.410, speed 103.61 f/s, eps 0.10
# 3421165: done 405 games, mean reward 15.560, speed 100.58 f/s, eps 0.10
# 3423316: done 406 games, mean reward 15.640, speed 104.65 f/s, eps 0.10
# 3423609: done 407 games, mean reward 15.630, speed 115.15 f/s, eps 0.10
# 3424126: done 408 games, mean reward 15.580, speed 88.59 f/s, eps 0.10
# 3427633: done 409 games, mean reward 16.120, speed 105.87 f/s, eps 0.10
# 3428165: done 410 games, mean reward 16.190, speed 94.84 f/s, eps 0.10
# 3428646: done 411 games, mean reward 15.930, speed 118.34 f/s, eps 0.10
# 3430037: done 412 games, mean reward 15.970, speed 113.38 f/s, eps 0.10
# 3430569: done 413 games, mean reward 15.930, speed 98.15 f/s, eps 0.10
# 3431653: done 414 games, mean reward 15.940, speed 108.00 f/s, eps 0.10
# 3434075: done 415 games, mean reward 16.160, speed 104.80 f/s, eps 0.10
# 3434270: done 416 games, mean reward 16.080, speed 89.68 f/s, eps 0.10
# 3434488: done 417 games, mean reward 16.060, speed 97.77 f/s, eps 0.10
# 3435392: done 418 games, mean reward 15.970, speed 111.06 f/s, eps 0.10
# 3436991: done 419 games, mean reward 16.210, speed 112.56 f/s, eps 0.10
# 3437562: done 420 games, mean reward 16.250, speed 106.34 f/s, eps 0.10
# 3439307: done 421 games, mean reward 16.410, speed 114.82 f/s, eps 0.10
# 3439486: done 422 games, mean reward 16.330, speed 109.35 f/s, eps 0.10
# 3440516: done 423 games, mean reward 16.240, speed 115.71 f/s, eps 0.10
# 3441526: done 424 games, mean reward 16.210, speed 115.68 f/s, eps 0.10
# 3442675: done 425 games, mean reward 16.240, speed 109.18 f/s, eps 0.10
# 3443951: done 426 games, mean reward 16.370, speed 104.99 f/s, eps 0.10
# 3444400: done 427 games, mean reward 16.190, speed 107.56 f/s, eps 0.10
# 3446076: done 428 games, mean reward 16.380, speed 107.89 f/s, eps 0.10
# 3446657: done 429 games, mean reward 16.370, speed 105.01 f/s, eps 0.10
# 3447951: done 430 games, mean reward 16.130, speed 96.50 f/s, eps 0.10
# 3448119: done 431 games, mean reward 16.120, speed 103.28 f/s, eps 0.10
# 3450402: done 432 games, mean reward 16.410, speed 111.64 f/s, eps 0.10
# 3452563: done 433 games, mean reward 16.400, speed 105.55 f/s, eps 0.10
# 3454135: done 434 games, mean reward 16.420, speed 112.54 f/s, eps 0.10
# 3454709: done 435 games, mean reward 16.450, speed 104.73 f/s, eps 0.10
# 3455704: done 436 games, mean reward 16.290, speed 109.50 f/s, eps 0.10
# 3456464: done 437 games, mean reward 16.270, speed 109.84 f/s, eps 0.10
# 3457080: done 438 games, mean reward 16.200, speed 111.67 f/s, eps 0.10
# 3457801: done 439 games, mean reward 16.200, speed 111.13 f/s, eps 0.10
# 3458395: done 440 games, mean reward 16.330, speed 101.27 f/s, eps 0.10
# 3459529: done 441 games, mean reward 16.370, speed 102.08 f/s, eps 0.10
# 3461577: done 442 games, mean reward 15.920, speed 107.99 f/s, eps 0.10
# 3461816: done 443 games, mean reward 15.880, speed 104.02 f/s, eps 0.10
# 3462040: done 444 games, mean reward 15.760, speed 118.13 f/s, eps 0.10
# 3462839: done 445 games, mean reward 15.760, speed 103.94 f/s, eps 0.10
# 3464323: done 446 games, mean reward 15.810, speed 109.77 f/s, eps 0.10
# 3466104: done 447 games, mean reward 16.060, speed 108.43 f/s, eps 0.10
# 3466832: done 448 games, mean reward 15.930, speed 106.96 f/s, eps 0.10
# 3467640: done 449 games, mean reward 15.950, speed 103.73 f/s, eps 0.10
# 3468940: done 450 games, mean reward 15.760, speed 103.86 f/s, eps 0.10
# 3469652: done 451 games, mean reward 15.810, speed 111.58 f/s, eps 0.10
# 3470038: done 452 games, mean reward 15.580, speed 113.79 f/s, eps 0.10
# 3470937: done 453 games, mean reward 15.610, speed 111.65 f/s, eps 0.10
# 3473902: done 454 games, mean reward 15.730, speed 103.01 f/s, eps 0.10
# 3475054: done 455 games, mean reward 15.840, speed 115.25 f/s, eps 0.10
# 3475363: done 456 games, mean reward 15.870, speed 114.14 f/s, eps 0.10
# 3478222: done 457 games, mean reward 16.310, speed 108.04 f/s, eps 0.10
# 3478794: done 458 games, mean reward 15.960, speed 110.87 f/s, eps 0.10
# 3479158: done 459 games, mean reward 15.830, speed 109.77 f/s, eps 0.10
# 3480724: done 460 games, mean reward 15.990, speed 110.18 f/s, eps 0.10
# 3480979: done 461 games, mean reward 15.730, speed 112.03 f/s, eps 0.10
# 3482818: done 462 games, mean reward 16.050, speed 109.61 f/s, eps 0.10
# 3483266: done 463 games, mean reward 16.140, speed 108.80 f/s, eps 0.10
# 3484564: done 464 games, mean reward 16.130, speed 112.00 f/s, eps 0.10
# 3485438: done 465 games, mean reward 16.200, speed 114.51 f/s, eps 0.10
# 3488116: done 466 games, mean reward 16.590, speed 109.32 f/s, eps 0.10
# 3489058: done 467 games, mean reward 16.610, speed 108.70 f/s, eps 0.10
# 3489444: done 468 games, mean reward 16.200, speed 110.76 f/s, eps 0.10
# 3490675: done 469 games, mean reward 16.170, speed 106.89 f/s, eps 0.10
# 3494164: done 470 games, mean reward 16.660, speed 103.80 f/s, eps 0.10
# 3494488: done 471 games, mean reward 16.390, speed 107.45 f/s, eps 0.10
# 3496093: done 472 games, mean reward 16.630, speed 102.60 f/s, eps 0.10
# 3498494: done 473 games, mean reward 16.680, speed 104.07 f/s, eps 0.10
# 3498971: done 474 games, mean reward 16.680, speed 93.16 f/s, eps 0.10
# 3499397: done 475 games, mean reward 16.740, speed 102.88 f/s, eps 0.10
# 3500619: done 476 games, mean reward 16.870, speed 102.82 f/s, eps 0.10
# 3500915: done 477 games, mean reward 16.680, speed 107.50 f/s, eps 0.10
# 3501642: done 478 games, mean reward 16.660, speed 107.49 f/s, eps 0.10
# 3503050: done 479 games, mean reward 16.620, speed 112.84 f/s, eps 0.10
# 3504076: done 480 games, mean reward 16.580, speed 110.87 f/s, eps 0.10
# 3504502: done 481 games, mean reward 16.510, speed 114.10 f/s, eps 0.10
# 3505285: done 482 games, mean reward 16.480, speed 113.53 f/s, eps 0.10
# 3506167: done 483 games, mean reward 16.570, speed 117.15 f/s, eps 0.10
# 3507362: done 484 games, mean reward 16.590, speed 117.29 f/s, eps 0.10
# 3508793: done 485 games, mean reward 16.560, speed 108.14 f/s, eps 0.10
# 3509413: done 486 games, mean reward 16.610, speed 106.36 f/s, eps 0.10
# 3511561: done 487 games, mean reward 16.720, speed 108.40 f/s, eps 0.10
# 3512966: done 488 games, mean reward 16.790, speed 110.98 f/s, eps 0.10
# 3514121: done 489 games, mean reward 16.770, speed 114.25 f/s, eps 0.10
# 3515392: done 490 games, mean reward 16.900, speed 109.73 f/s, eps 0.10
# 3517056: done 491 games, mean reward 17.020, speed 108.89 f/s, eps 0.10
# 3518004: done 492 games, mean reward 17.100, speed 109.79 f/s, eps 0.10
# 3520266: done 493 games, mean reward 16.970, speed 100.98 f/s, eps 0.10
# 3521598: done 494 games, mean reward 17.120, speed 107.48 f/s, eps 0.10
# 3521870: done 495 games, mean reward 17.060, speed 108.89 f/s, eps 0.10
# 3522924: done 496 games, mean reward 17.060, speed 102.90 f/s, eps 0.10
# 3523225: done 497 games, mean reward 16.960, speed 102.69 f/s, eps 0.10
# 3523900: done 498 games, mean reward 16.750, speed 106.78 f/s, eps 0.10
# 3525257: done 499 games, mean reward 16.960, speed 101.09 f/s, eps 0.10
# 3526796: done 500 games, mean reward 16.810, speed 108.45 f/s, eps 0.10
# 3527260: done 501 games, mean reward 16.770, speed 99.07 f/s, eps 0.10
# 3529393: done 502 games, mean reward 16.920, speed 100.78 f/s, eps 0.10
# 3530051: done 503 games, mean reward 16.890, speed 103.19 f/s, eps 0.10
# 3530484: done 504 games, mean reward 16.860, speed 121.03 f/s, eps 0.10
# 3531956: done 505 games, mean reward 16.880, speed 111.03 f/s, eps 0.10
# 3532121: done 506 games, mean reward 16.530, speed 108.09 f/s, eps 0.10
# 3532357: done 507 games, mean reward 16.530, speed 109.29 f/s, eps 0.10
# 3533405: done 508 games, mean reward 16.660, speed 112.53 f/s, eps 0.10
# 3534183: done 509 games, mean reward 16.120, speed 114.06 f/s, eps 0.10
# 3534707: done 510 games, mean reward 16.030, speed 111.36 f/s, eps 0.10
# 3537669: done 511 games, mean reward 16.410, speed 110.40 f/s, eps 0.10
# 3537856: done 512 games, mean reward 16.220, speed 107.93 f/s, eps 0.10
# 3538617: done 513 games, mean reward 16.230, speed 105.92 f/s, eps 0.10
# 3540007: done 514 games, mean reward 16.220, speed 104.73 f/s, eps 0.10
# 3540815: done 515 games, mean reward 15.840, speed 115.09 f/s, eps 0.10
# 3541053: done 516 games, mean reward 15.840, speed 111.22 f/s, eps 0.10
# 3542859: done 517 games, mean reward 16.110, speed 109.47 f/s, eps 0.10
# 3544349: done 518 games, mean reward 16.270, speed 104.27 f/s, eps 0.10
# 3544742: done 519 games, mean reward 16.030, speed 112.85 f/s, eps 0.10
# 3546152: done 520 games, mean reward 16.130, speed 97.50 f/s, eps 0.10
# 3547098: done 521 games, mean reward 15.920, speed 96.28 f/s, eps 0.10
# 3547521: done 522 games, mean reward 15.990, speed 100.52 f/s, eps 0.10
# 3548974: done 523 games, mean reward 16.150, speed 102.81 f/s, eps 0.10
# 3549695: done 524 games, mean reward 16.180, speed 103.76 f/s, eps 0.10
# 3550170: done 525 games, mean reward 16.070, speed 111.89 f/s, eps 0.10
# 3551770: done 526 games, mean reward 16.210, speed 101.27 f/s, eps 0.10
# 3551984: done 527 games, mean reward 16.150, speed 114.59 f/s, eps 0.10
# 3553637: done 528 games, mean reward 16.190, speed 113.86 f/s, eps 0.10
# 3554470: done 529 games, mean reward 16.240, speed 119.90 f/s, eps 0.10
# 3555883: done 530 games, mean reward 16.300, speed 103.17 f/s, eps 0.10
# 3557024: done 531 games, mean reward 16.490, speed 116.03 f/s, eps 0.10
# 3557628: done 532 games, mean reward 16.230, speed 117.61 f/s, eps 0.10
# 3558366: done 533 games, mean reward 15.920, speed 113.76 f/s, eps 0.10
# 3558638: done 534 games, mean reward 15.710, speed 106.79 f/s, eps 0.10
# 3559450: done 535 games, mean reward 15.770, speed 119.01 f/s, eps 0.10
# 3559964: done 536 games, mean reward 15.670, speed 109.37 f/s, eps 0.10
# 3561349: done 537 games, mean reward 15.670, speed 110.15 f/s, eps 0.10
# 3564408: done 538 games, mean reward 16.110, speed 118.79 f/s, eps 0.10
# 3565250: done 539 games, mean reward 16.070, speed 104.00 f/s, eps 0.10
# 3566284: done 540 games, mean reward 16.110, speed 117.00 f/s, eps 0.10
# 3567681: done 541 games, mean reward 16.270, speed 117.83 f/s, eps 0.10
# 3567918: done 542 games, mean reward 15.970, speed 122.22 f/s, eps 0.10
# 3568768: done 543 games, mean reward 16.090, speed 110.65 f/s, eps 0.10
# 3569314: done 544 games, mean reward 16.190, speed 114.16 f/s, eps 0.10
# 3569642: done 545 games, mean reward 16.070, speed 115.19 f/s, eps 0.10
# 3570291: done 546 games, mean reward 16.040, speed 122.37 f/s, eps 0.10
# 3571874: done 547 games, mean reward 16.020, speed 115.68 f/s, eps 0.10
# 3573014: done 548 games, mean reward 16.040, speed 106.73 f/s, eps 0.10
# 3573442: done 549 games, mean reward 15.970, speed 113.51 f/s, eps 0.10
# 3574756: done 550 games, mean reward 16.040, speed 107.37 f/s, eps 0.10
# 3575608: done 551 games, mean reward 15.990, speed 110.20 f/s, eps 0.10
# 3576228: done 552 games, mean reward 16.090, speed 110.14 f/s, eps 0.10
# 3577544: done 553 games, mean reward 16.130, speed 116.81 f/s, eps 0.10
# 3579874: done 554 games, mean reward 16.100, speed 114.51 f/s, eps 0.10
# 3580401: done 555 games, mean reward 16.020, speed 111.83 f/s, eps 0.10
# 3581957: done 556 games, mean reward 16.260, speed 114.52 f/s, eps 0.10
# 3582942: done 557 games, mean reward 15.880, speed 116.63 f/s, eps 0.10
# 3583385: done 558 games, mean reward 15.830, speed 116.76 f/s, eps 0.10
# 3584825: done 559 games, mean reward 16.030, speed 111.95 f/s, eps 0.10
# 3585884: done 560 games, mean reward 15.870, speed 113.95 f/s, eps 0.10
# 3588310: done 561 games, mean reward 16.250, speed 117.13 f/s, eps 0.10
# 3591014: done 562 games, mean reward 16.380, speed 113.59 f/s, eps 0.10
# 3593064: done 563 games, mean reward 16.640, speed 115.70 f/s, eps 0.10
# 3593245: done 564 games, mean reward 16.450, speed 112.26 f/s, eps 0.10
# 3596033: done 565 games, mean reward 16.780, speed 117.66 f/s, eps 0.10
# 3596570: done 566 games, mean reward 16.450, speed 108.43 f/s, eps 0.10
# 3597745: done 567 games, mean reward 16.380, speed 114.79 f/s, eps 0.10
# 3598520: done 568 games, mean reward 16.490, speed 120.38 f/s, eps 0.10
# 3598687: done 569 games, mean reward 16.330, speed 113.99 f/s, eps 0.10
# 3599671: done 570 games, mean reward 15.900, speed 116.26 f/s, eps 0.10
# 3600049: done 571 games, mean reward 15.920, speed 114.61 f/s, eps 0.10
# 3601265: done 572 games, mean reward 15.770, speed 121.11 f/s, eps 0.10
# 3602098: done 573 games, mean reward 15.520, speed 118.02 f/s, eps 0.10
# 3603884: done 574 games, mean reward 15.730, speed 118.06 f/s, eps 0.10
# 3604078: done 575 games, mean reward 15.650, speed 113.24 f/s, eps 0.10
# 3607018: done 576 games, mean reward 15.850, speed 119.39 f/s, eps 0.10
# 3607641: done 577 games, mean reward 15.920, speed 115.16 f/s, eps 0.10
# 3608284: done 578 games, mean reward 15.920, speed 112.15 f/s, eps 0.10
# 3610115: done 579 games, mean reward 16.010, speed 105.79 f/s, eps 0.10
# 3610329: done 580 games, mean reward 15.920, speed 106.49 f/s, eps 0.10
# 3611528: done 581 games, mean reward 16.080, speed 115.47 f/s, eps 0.10
# 3614848: done 582 games, mean reward 16.480, speed 114.88 f/s, eps 0.10
# 3615947: done 583 games, mean reward 16.480, speed 117.59 f/s, eps 0.10
# 3617354: done 584 games, mean reward 16.460, speed 112.42 f/s, eps 0.10
# 3617612: done 585 games, mean reward 16.280, speed 115.23 f/s, eps 0.10
# 3617909: done 586 games, mean reward 16.230, speed 117.19 f/s, eps 0.10
# 3618704: done 587 games, mean reward 16.080, speed 115.90 f/s, eps 0.10
# 3618950: done 588 games, mean reward 15.890, speed 123.01 f/s, eps 0.10
# 3622133: done 589 games, mean reward 16.200, speed 114.21 f/s, eps 0.10
# 3623722: done 590 games, mean reward 16.270, speed 112.52 f/s, eps 0.10
# 3624239: done 591 games, mean reward 16.110, speed 116.70 f/s, eps 0.10
# 3624775: done 592 games, mean reward 16.050, speed 121.01 f/s, eps 0.10
# 3625991: done 593 games, mean reward 15.910, speed 112.59 f/s, eps 0.10
# 3627818: done 594 games, mean reward 15.990, speed 117.04 f/s, eps 0.10
# 3628506: done 595 games, mean reward 16.090, speed 118.45 f/s, eps 0.10
# 3629719: done 596 games, mean reward 16.110, speed 120.06 f/s, eps 0.10
# 3629945: done 597 games, mean reward 16.080, speed 115.89 f/s, eps 0.10
# 3630180: done 598 games, mean reward 16.020, speed 115.43 f/s, eps 0.10
# 3631867: done 599 games, mean reward 16.070, speed 115.93 f/s, eps 0.10
# 3632031: done 600 games, mean reward 15.920, speed 105.09 f/s, eps 0.10
# 3633938: done 601 games, mean reward 16.160, speed 117.95 f/s, eps 0.10
# 3635679: done 602 games, mean reward 16.120, speed 116.60 f/s, eps 0.10
# 3636243: done 603 games, mean reward 16.010, speed 114.96 f/s, eps 0.10
# 3636813: done 604 games, mean reward 16.050, speed 117.50 f/s, eps 0.10
# 3638945: done 605 games, mean reward 16.050, speed 117.76 f/s, eps 0.10
# 3639663: done 606 games, mean reward 16.180, speed 117.12 f/s, eps 0.10
# 3640938: done 607 games, mean reward 16.330, speed 114.78 f/s, eps 0.10
# 3641687: done 608 games, mean reward 16.280, speed 111.59 f/s, eps 0.10
# 3642256: done 609 games, mean reward 16.210, speed 117.18 f/s, eps 0.10
# 3643889: done 610 games, mean reward 16.340, speed 115.95 f/s, eps 0.10
# 3644777: done 611 games, mean reward 16.020, speed 112.88 f/s, eps 0.10
# 3645202: done 612 games, mean reward 16.060, speed 115.22 f/s, eps 0.10
# 3647856: done 613 games, mean reward 16.390, speed 115.51 f/s, eps 0.10
# 3650528: done 614 games, mean reward 16.700, speed 117.71 f/s, eps 0.10
# 3651430: done 615 games, mean reward 16.770, speed 111.22 f/s, eps 0.10
# 3652742: done 616 games, mean reward 16.960, speed 109.45 f/s, eps 0.10
# 3654053: done 617 games, mean reward 16.810, speed 110.23 f/s, eps 0.10
# 3654775: done 618 games, mean reward 16.630, speed 110.93 f/s, eps 0.10
# 3655564: done 619 games, mean reward 16.660, speed 118.98 f/s, eps 0.10
# 3656947: done 620 games, mean reward 16.630, speed 111.99 f/s, eps 0.10
# 3657173: done 621 games, mean reward 16.560, speed 115.15 f/s, eps 0.10
# 3658862: done 622 games, mean reward 16.710, speed 121.06 f/s, eps 0.10
# 3660622: done 623 games, mean reward 16.700, speed 115.56 f/s, eps 0.10
# 3661261: done 624 games, mean reward 16.620, speed 116.92 f/s, eps 0.10
# 3661554: done 625 games, mean reward 16.590, speed 99.31 f/s, eps 0.10
# 3662073: done 626 games, mean reward 16.380, speed 116.53 f/s, eps 0.10
# 3663233: done 627 games, mean reward 16.530, speed 117.28 f/s, eps 0.10
# 3663858: done 628 games, mean reward 16.330, speed 121.71 f/s, eps 0.10
# 3664656: done 629 games, mean reward 16.330, speed 115.36 f/s, eps 0.10
# 3665008: done 630 games, mean reward 16.160, speed 111.29 f/s, eps 0.10
# 3666173: done 631 games, mean reward 16.050, speed 113.94 f/s, eps 0.10
# 3666576: done 632 games, mean reward 15.960, speed 118.68 f/s, eps 0.10
# 3667711: done 633 games, mean reward 16.060, speed 118.68 f/s, eps 0.10
# 3669076: done 634 games, mean reward 16.260, speed 113.78 f/s, eps 0.10
# 3670177: done 635 games, mean reward 16.260, speed 119.02 f/s, eps 0.10
# 3670587: done 636 games, mean reward 16.270, speed 102.47 f/s, eps 0.10
# 3671443: done 637 games, mean reward 16.250, speed 114.09 f/s, eps 0.10
# 3673059: done 638 games, mean reward 16.050, speed 110.97 f/s, eps 0.10
# 3673292: done 639 games, mean reward 15.940, speed 109.07 f/s, eps 0.10
# 3673545: done 640 games, mean reward 15.780, speed 120.17 f/s, eps 0.10
# 3675017: done 641 games, mean reward 15.770, speed 118.14 f/s, eps 0.10
# 3675667: done 642 games, mean reward 15.790, speed 115.37 f/s, eps 0.10
# 3676129: done 643 games, mean reward 15.760, speed 118.69 f/s, eps 0.10
# 3677869: done 644 games, mean reward 15.940, speed 120.61 f/s, eps 0.10
# 3678812: done 645 games, mean reward 16.040, speed 115.31 f/s, eps 0.10
# 3679101: done 646 games, mean reward 15.940, speed 107.43 f/s, eps 0.10
# 3680026: done 647 games, mean reward 15.820, speed 115.18 f/s, eps 0.10
# 3680539: done 648 games, mean reward 15.740, speed 105.41 f/s, eps 0.10
# 3681929: done 649 games, mean reward 15.890, speed 114.14 f/s, eps 0.10
# 3682384: done 650 games, mean reward 15.750, speed 114.96 f/s, eps 0.10
# 3682899: done 651 games, mean reward 15.730, speed 123.24 f/s, eps 0.10
# 3683272: done 652 games, mean reward 15.660, speed 113.47 f/s, eps 0.10
# 3684106: done 653 games, mean reward 15.620, speed 111.65 f/s, eps 0.10
# 3684845: done 654 games, mean reward 15.380, speed 119.44 f/s, eps 0.10
# 3685548: done 655 games, mean reward 15.380, speed 117.71 f/s, eps 0.10
# 3687511: done 656 games, mean reward 15.390, speed 117.27 f/s, eps 0.10
# 3687726: done 657 games, mean reward 15.280, speed 115.85 f/s, eps 0.10
# 3687965: done 658 games, mean reward 15.260, speed 114.36 f/s, eps 0.10
# 3689679: done 659 games, mean reward 15.310, speed 115.29 f/s, eps 0.10
# 3690143: done 660 games, mean reward 15.250, speed 116.89 f/s, eps 0.10
# 3690359: done 661 games, mean reward 14.870, speed 120.69 f/s, eps 0.10
# 3691371: done 662 games, mean reward 14.590, speed 116.25 f/s, eps 0.10
# 3691674: done 663 games, mean reward 14.280, speed 112.83 f/s, eps 0.10
# 3692983: done 664 games, mean reward 14.480, speed 109.61 f/s, eps 0.10
# 3694803: done 665 games, mean reward 14.330, speed 111.19 f/s, eps 0.10
# 3695050: done 666 games, mean reward 14.260, speed 98.38 f/s, eps 0.10
# 3696237: done 667 games, mean reward 14.320, speed 116.87 f/s, eps 0.10
# 3697919: done 668 games, mean reward 14.490, speed 116.06 f/s, eps 0.10
# ...
# 5775268: done 2661 games, mean reward 15.400, speed 107.98 f/s, eps 0.10
# 5775863: done 2662 games, mean reward 15.480, speed 103.46 f/s, eps 0.10
# 5777326: done 2663 games, mean reward 15.540, speed 110.60 f/s, eps 0.10
# 5779137: done 2664 games, mean reward 15.560, speed 117.67 f/s, eps 0.10
# 5782165: done 2665 games, mean reward 16.030, speed 120.46 f/s, eps 0.10
# 5782522: done 2666 games, mean reward 15.940, speed 103.43 f/s, eps 0.10
# 5783115: done 2667 games, mean reward 15.890, speed 112.84 f/s, eps 0.10
# 5784714: done 2668 games, mean reward 16.050, speed 108.40 f/s, eps 0.10
# 5785041: done 2669 games, mean reward 16.030, speed 109.89 f/s, eps 0.10
# 5785523: done 2670 games, mean reward 15.860, speed 112.23 f/s, eps 0.10
# 5786008: done 2671 games, mean reward 15.920, speed 108.37 f/s, eps 0.10
# 5786461: done 2672 games, mean reward 15.900, speed 103.65 f/s, eps 0.10
# 5786668: done 2673 games, mean reward 15.750, speed 124.16 f/s, eps 0.10
# 5787966: done 2674 games, mean reward 15.880, speed 118.54 f/s, eps 0.10
# 5789500: done 2675 games, mean reward 15.890, speed 108.08 f/s, eps 0.10
# 5789708: done 2676 games, mean reward 15.750, speed 109.97 f/s, eps 0.10
# 5790580: done 2677 games, mean reward 15.770, speed 114.56 f/s, eps 0.10
# 5791428: done 2678 games, mean reward 15.790, speed 122.26 f/s, eps 0.10
# 5791840: done 2679 games, mean reward 15.670, speed 114.87 f/s, eps 0.10
# 5792309: done 2680 games, mean reward 15.640, speed 113.03 f/s, eps 0.10
# 5792849: done 2681 games, mean reward 15.570, speed 110.66 f/s, eps 0.10
# 5794166: done 2682 games, mean reward 15.670, speed 121.28 f/s, eps 0.10
# 5796364: done 2683 games, mean reward 15.900, speed 113.05 f/s, eps 0.10
# 5796523: done 2684 games, mean reward 15.360, speed 113.37 f/s, eps 0.10
# 5797722: done 2685 games, mean reward 15.450, speed 118.83 f/s, eps 0.10
# 5800020: done 2686 games, mean reward 15.600, speed 112.73 f/s, eps 0.10
# 5801466: done 2687 games, mean reward 15.740, speed 112.66 f/s, eps 0.10
# 5801671: done 2688 games, mean reward 15.500, speed 111.10 f/s, eps 0.10
# 5802953: done 2689 games, mean reward 15.690, speed 105.76 f/s, eps 0.10
# 5803861: done 2690 games, mean reward 15.630, speed 111.95 f/s, eps 0.10
# 5805552: done 2691 games, mean reward 15.490, speed 105.33 f/s, eps 0.10
# 5806025: done 2692 games, mean reward 15.420, speed 106.51 f/s, eps 0.10
# 5807483: done 2693 games, mean reward 15.590, speed 115.92 f/s, eps 0.10
# 5808567: done 2694 games, mean reward 15.470, speed 116.89 f/s, eps 0.10
# 5809713: done 2695 games, mean reward 15.650, speed 111.33 f/s, eps 0.10
# 5810528: done 2696 games, mean reward 15.750, speed 117.21 f/s, eps 0.10
# 5811827: done 2697 games, mean reward 15.760, speed 111.46 f/s, eps 0.10
# 5812955: done 2698 games, mean reward 15.870, speed 108.39 f/s, eps 0.10
# 5814531: done 2699 games, mean reward 16.080, speed 115.13 f/s, eps 0.10
# 5815256: done 2700 games, mean reward 15.620, speed 121.39 f/s, eps 0.10
# 5816340: done 2701 games, mean reward 15.770, speed 114.59 f/s, eps 0.10
# 5817987: done 2702 games, mean reward 15.960, speed 115.78 f/s, eps 0.10
# 5818753: done 2703 games, mean reward 15.760, speed 119.61 f/s, eps 0.10
# 5819183: done 2704 games, mean reward 15.790, speed 104.50 f/s, eps 0.10
# 5819949: done 2705 games, mean reward 15.760, speed 109.65 f/s, eps 0.10
# 5820318: done 2706 games, mean reward 15.620, speed 101.64 f/s, eps 0.10
# 5820981: done 2707 games, mean reward 15.220, speed 109.05 f/s, eps 0.10
# 5821403: done 2708 games, mean reward 15.210, speed 115.31 f/s, eps 0.10
# 5822739: done 2709 games, mean reward 15.400, speed 107.30 f/s, eps 0.10
# 5823804: done 2710 games, mean reward 14.950, speed 113.33 f/s, eps 0.10
# 5825026: done 2711 games, mean reward 15.030, speed 109.87 f/s, eps 0.10
# 5825484: done 2712 games, mean reward 15.070, speed 112.93 f/s, eps 0.10
# 5826725: done 2713 games, mean reward 15.100, speed 105.60 f/s, eps 0.10
# 5828071: done 2714 games, mean reward 15.330, speed 105.49 f/s, eps 0.10
# 5828231: done 2715 games, mean reward 15.130, speed 116.45 f/s, eps 0.10
# 5830169: done 2716 games, mean reward 15.280, speed 109.02 f/s, eps 0.10
# 5830692: done 2717 games, mean reward 15.210, speed 113.55 f/s, eps 0.10
# 5831271: done 2718 games, mean reward 15.250, speed 122.23 f/s, eps 0.10
# 5831655: done 2719 games, mean reward 15.190, speed 116.04 f/s, eps 0.10
# 5834761: done 2720 games, mean reward 15.570, speed 114.70 f/s, eps 0.10
# 5834994: done 2721 games, mean reward 15.370, speed 102.23 f/s, eps 0.10
# 5835328: done 2722 games, mean reward 15.340, speed 109.23 f/s, eps 0.10
# 5837359: done 2723 games, mean reward 15.640, speed 114.17 f/s, eps 0.10
# 5837809: done 2724 games, mean reward 15.620, speed 114.42 f/s, eps 0.10
# 5837974: done 2725 games, mean reward 15.380, speed 118.62 f/s, eps 0.10
# 5839443: done 2726 games, mean reward 15.660, speed 110.32 f/s, eps 0.10
# 5840662: done 2727 games, mean reward 15.600, speed 116.16 f/s, eps 0.10
# 5841592: done 2728 games, mean reward 15.490, speed 117.04 f/s, eps 0.10
# 5842925: done 2729 games, mean reward 15.640, speed 113.57 f/s, eps 0.10
# 5843806: done 2730 games, mean reward 15.710, speed 110.92 f/s, eps 0.10
# 5844559: done 2731 games, mean reward 15.770, speed 108.74 f/s, eps 0.10
# 5845335: done 2732 games, mean reward 15.680, speed 111.51 f/s, eps 0.10
# 5846100: done 2733 games, mean reward 15.760, speed 112.73 f/s, eps 0.10
# 5847333: done 2734 games, mean reward 15.240, speed 111.60 f/s, eps 0.10
# 5847971: done 2735 games, mean reward 15.290, speed 119.45 f/s, eps 0.10
# 5848668: done 2736 games, mean reward 15.330, speed 105.09 f/s, eps 0.10
# 5849580: done 2737 games, mean reward 14.840, speed 109.17 f/s, eps 0.10
# 5850270: done 2738 games, mean reward 14.950, speed 113.49 f/s, eps 0.10
# 5851160: done 2739 games, mean reward 15.020, speed 108.16 f/s, eps 0.10
# 5852171: done 2740 games, mean reward 15.090, speed 120.86 f/s, eps 0.10
# 5855530: done 2741 games, mean reward 15.590, speed 112.03 f/s, eps 0.10
# 5856102: done 2742 games, mean reward 15.260, speed 109.52 f/s, eps 0.10
# 5856400: done 2743 games, mean reward 15.250, speed 106.55 f/s, eps 0.10
# 5857929: done 2744 games, mean reward 15.410, speed 117.69 f/s, eps 0.10
# 5859537: done 2745 games, mean reward 15.410, speed 110.02 f/s, eps 0.10
# 5860273: done 2746 games, mean reward 15.520, speed 108.09 f/s, eps 0.10
# 5861032: done 2747 games, mean reward 15.370, speed 117.14 f/s, eps 0.10
# 5862126: done 2748 games, mean reward 15.420, speed 104.92 f/s, eps 0.10
# 5863085: done 2749 games, mean reward 15.500, speed 117.51 f/s, eps 0.10
# 5864118: done 2750 games, mean reward 15.300, speed 105.74 f/s, eps 0.10
# 5865055: done 2751 games, mean reward 15.140, speed 116.04 f/s, eps 0.10
# 5865333: done 2752 games, mean reward 15.020, speed 104.76 f/s, eps 0.10
# 5868465: done 2753 games, mean reward 15.420, speed 112.48 f/s, eps 0.10
# 5868792: done 2754 games, mean reward 15.320, speed 111.35 f/s, eps 0.10
# 5869882: done 2755 games, mean reward 15.330, speed 108.47 f/s, eps 0.10
# 5870374: done 2756 games, mean reward 15.120, speed 111.34 f/s, eps 0.10
# 5871093: done 2757 games, mean reward 15.190, speed 105.63 f/s, eps 0.10
# 5871934: done 2758 games, mean reward 15.180, speed 112.82 f/s, eps 0.10
# 5872391: done 2759 games, mean reward 14.890, speed 86.62 f/s, eps 0.10
# 5874352: done 2760 games, mean reward 15.090, speed 111.45 f/s, eps 0.10
# 5874715: done 2761 games, mean reward 15.090, speed 112.61 f/s, eps 0.10
# 5876384: done 2762 games, mean reward 15.310, speed 110.96 f/s, eps 0.10
# 5877050: done 2763 games, mean reward 15.230, speed 114.89 f/s, eps 0.10
# 5877702: done 2764 games, mean reward 15.040, speed 121.41 f/s, eps 0.10
# 5879958: done 2765 games, mean reward 14.920, speed 108.47 f/s, eps 0.10
# 5880489: done 2766 games, mean reward 14.950, speed 118.17 f/s, eps 0.10
# 5880953: done 2767 games, mean reward 14.900, speed 106.30 f/s, eps 0.10
# 5882837: done 2768 games, mean reward 14.910, speed 116.55 f/s, eps 0.10
# 5882997: done 2769 games, mean reward 14.900, speed 99.16 f/s, eps 0.10
# 5883518: done 2770 games, mean reward 14.930, speed 105.88 f/s, eps 0.10
# 5886357: done 2771 games, mean reward 15.320, speed 116.64 f/s, eps 0.10
# 5887040: done 2772 games, mean reward 15.380, speed 109.72 f/s, eps 0.10
# 5887534: done 2773 games, mean reward 15.490, speed 115.41 f/s, eps 0.10
# 5890645: done 2774 games, mean reward 15.750, speed 112.14 f/s, eps 0.10
# 5890881: done 2775 games, mean reward 15.570, speed 111.32 f/s, eps 0.10
# 5891947: done 2776 games, mean reward 15.760, speed 117.53 f/s, eps 0.10
# 5893101: done 2777 games, mean reward 15.830, speed 116.62 f/s, eps 0.10
# 5893279: done 2778 games, mean reward 15.720, speed 114.21 f/s, eps 0.10
# 5893705: done 2779 games, mean reward 15.740, speed 95.68 f/s, eps 0.10
# 5896037: done 2780 games, mean reward 16.040, speed 119.56 f/s, eps 0.10
# 5898268: done 2781 games, mean reward 16.360, speed 110.40 f/s, eps 0.10
# 5899122: done 2782 games, mean reward 16.270, speed 111.21 f/s, eps 0.10
# 5899655: done 2783 games, mean reward 16.010, speed 100.94 f/s, eps 0.10
# 5901442: done 2784 games, mean reward 16.200, speed 115.42 f/s, eps 0.10
# 5903064: done 2785 games, mean reward 16.260, speed 119.96 f/s, eps 0.10
# 5904713: done 2786 games, mean reward 16.240, speed 107.25 f/s, eps 0.10
# 5905651: done 2787 games, mean reward 16.080, speed 112.18 f/s, eps 0.10
# 5906197: done 2788 games, mean reward 16.110, speed 114.55 f/s, eps 0.10
# 5906924: done 2789 games, mean reward 16.020, speed 115.37 f/s, eps 0.10
# 5910035: done 2790 games, mean reward 16.460, speed 115.34 f/s, eps 0.10
# 5910494: done 2791 games, mean reward 16.220, speed 106.97 f/s, eps 0.10
# 5910840: done 2792 games, mean reward 16.190, speed 112.77 f/s, eps 0.10
# 5911697: done 2793 games, mean reward 16.130, speed 121.53 f/s, eps 0.10
# 5913323: done 2794 games, mean reward 16.200, speed 118.36 f/s, eps 0.10
# 5913814: done 2795 games, mean reward 16.120, speed 107.45 f/s, eps 0.10
# 5914317: done 2796 games, mean reward 16.060, speed 109.23 f/s, eps 0.10
# 5914991: done 2797 games, mean reward 16.000, speed 105.40 f/s, eps 0.10
# 5917957: done 2798 games, mean reward 16.370, speed 109.69 f/s, eps 0.10
# 5918284: done 2799 games, mean reward 16.130, speed 108.65 f/s, eps 0.10
# 5919735: done 2800 games, mean reward 16.310, speed 106.11 f/s, eps 0.10
# 5920471: done 2801 games, mean reward 16.260, speed 103.05 f/s, eps 0.10
# 5921557: done 2802 games, mean reward 16.150, speed 114.11 f/s, eps 0.10
# 5922752: done 2803 games, mean reward 16.340, speed 113.95 f/s, eps 0.10
# 5923375: done 2804 games, mean reward 16.420, speed 114.79 f/s, eps 0.10
# 5924348: done 2805 games, mean reward 16.420, speed 107.62 f/s, eps 0.10
# 5924844: done 2806 games, mean reward 16.410, speed 112.26 f/s, eps 0.10
# 5927558: done 2807 games, mean reward 16.850, speed 115.03 f/s, eps 0.10
# 5928082: done 2808 games, mean reward 16.870, speed 119.93 f/s, eps 0.10
# 5928832: done 2809 games, mean reward 16.810, speed 118.68 f/s, eps 0.10
# 5930614: done 2810 games, mean reward 17.100, speed 114.17 f/s, eps 0.10
# 5931031: done 2811 games, mean reward 16.960, speed 105.35 f/s, eps 0.10
# 5931307: done 2812 games, mean reward 16.900, speed 113.73 f/s, eps 0.10
# 5932048: done 2813 games, mean reward 16.930, speed 111.82 f/s, eps 0.10
# 5932409: done 2814 games, mean reward 16.690, speed 130.83 f/s, eps 0.10
# 5934349: done 2815 games, mean reward 16.940, speed 113.75 f/s, eps 0.10
# 5936651: done 2816 games, mean reward 16.930, speed 116.60 f/s, eps 0.10
# 5936874: done 2817 games, mean reward 16.890, speed 113.97 f/s, eps 0.10
# 5937867: done 2818 games, mean reward 16.970, speed 111.98 f/s, eps 0.10
# 5939206: done 2819 games, mean reward 17.160, speed 113.69 f/s, eps 0.10
# 5939841: done 2820 games, mean reward 16.730, speed 110.92 f/s, eps 0.10
# 5942156: done 2821 games, mean reward 17.130, speed 114.03 f/s, eps 0.10
# 5942845: done 2822 games, mean reward 17.250, speed 125.14 f/s, eps 0.10
# 5943820: done 2823 games, mean reward 17.090, speed 109.75 f/s, eps 0.10
# 5944716: done 2824 games, mean reward 17.150, speed 90.51 f/s, eps 0.10
# 5945382: done 2825 games, mean reward 17.220, speed 115.12 f/s, eps 0.10
# 5947174: done 2826 games, mean reward 17.170, speed 115.43 f/s, eps 0.10
# 5948809: done 2827 games, mean reward 17.300, speed 112.96 f/s, eps 0.10
# 5949810: done 2828 games, mean reward 17.340, speed 113.88 f/s, eps 0.10
# 5952177: done 2829 games, mean reward 17.550, speed 113.92 f/s, eps 0.10
# 5952445: done 2830 games, mean reward 17.440, speed 117.83 f/s, eps 0.10
# 5953013: done 2831 games, mean reward 17.400, speed 114.55 f/s, eps 0.10
# 5953318: done 2832 games, mean reward 17.310, speed 116.81 f/s, eps 0.10
# 5953976: done 2833 games, mean reward 17.320, speed 118.93 f/s, eps 0.10
# 5957052: done 2834 games, mean reward 17.590, speed 117.09 f/s, eps 0.10
# 5957788: done 2835 games, mean reward 17.590, speed 112.94 f/s, eps 0.10
# 5958386: done 2836 games, mean reward 17.620, speed 114.64 f/s, eps 0.10
# 5960019: done 2837 games, mean reward 17.800, speed 111.83 f/s, eps 0.10
# 5960588: done 2838 games, mean reward 17.740, speed 118.06 f/s, eps 0.10
# 5962409: done 2839 games, mean reward 17.850, speed 117.48 f/s, eps 0.10
# 5963079: done 2840 games, mean reward 17.850, speed 111.74 f/s, eps 0.10
# 5963556: done 2841 games, mean reward 17.370, speed 98.41 f/s, eps 0.10
# 5963952: done 2842 games, mean reward 17.390, speed 96.83 f/s, eps 0.10
# 5964408: done 2843 games, mean reward 17.460, speed 104.41 f/s, eps 0.10
# 5964730: done 2844 games, mean reward 17.210, speed 112.34 f/s, eps 0.10
# 5965429: done 2845 games, mean reward 17.010, speed 116.63 f/s, eps 0.10
# 5966714: done 2846 games, mean reward 17.130, speed 106.21 f/s, eps 0.10
# 5967242: done 2847 games, mean reward 17.030, speed 106.91 f/s, eps 0.10
# 5967958: done 2848 games, mean reward 16.960, speed 107.87 f/s, eps 0.10
# 5968606: done 2849 games, mean reward 16.980, speed 115.18 f/s, eps 0.10
# 5970335: done 2850 games, mean reward 17.140, speed 109.03 f/s, eps 0.10
# 5970942: done 2851 games, mean reward 17.130, speed 110.28 f/s, eps 0.10
# 5971631: done 2852 games, mean reward 17.260, speed 106.32 f/s, eps 0.10
# 5971987: done 2853 games, mean reward 16.780, speed 104.87 f/s, eps 0.10
# 5973980: done 2854 games, mean reward 16.960, speed 114.70 f/s, eps 0.10
# 5975054: done 2855 games, mean reward 17.000, speed 110.84 f/s, eps 0.10
# 5975271: done 2856 games, mean reward 16.940, speed 107.63 f/s, eps 0.10
# 5975699: done 2857 games, mean reward 16.930, speed 109.34 f/s, eps 0.10
# 5977769: done 2858 games, mean reward 17.120, speed 113.69 f/s, eps 0.10
# 5977996: done 2859 games, mean reward 17.050, speed 101.84 f/s, eps 0.10
# 5978990: done 2860 games, mean reward 16.880, speed 100.20 f/s, eps 0.10
# 5979997: done 2861 games, mean reward 17.010, speed 109.13 f/s, eps 0.10
# 5981670: done 2862 games, mean reward 16.950, speed 114.02 f/s, eps 0.10
# 5981851: done 2863 games, mean reward 16.820, speed 113.60 f/s, eps 0.10
# 5982498: done 2864 games, mean reward 16.870, speed 113.80 f/s, eps 0.10
# 5984252: done 2865 games, mean reward 16.800, speed 107.91 f/s, eps 0.10
# 5984540: done 2866 games, mean reward 16.750, speed 112.79 f/s, eps 0.10
# 5987704: done 2867 games, mean reward 17.220, speed 113.74 f/s, eps 0.10
# 5988032: done 2868 games, mean reward 16.940, speed 115.73 f/s, eps 0.10
# 5988505: done 2869 games, mean reward 17.010, speed 107.91 f/s, eps 0.10
# 5991523: done 2870 games, mean reward 17.370, speed 110.20 f/s, eps 0.10
# 5992382: done 2871 games, mean reward 17.040, speed 109.16 f/s, eps 0.10
# 5992813: done 2872 games, mean reward 17.000, speed 106.36 f/s, eps 0.10
# 5993788: done 2873 games, mean reward 17.040, speed 114.02 f/s, eps 0.10
# 5994971: done 2874 games, mean reward 16.750, speed 111.64 f/s, eps 0.10
# 5995477: done 2875 games, mean reward 16.820, speed 111.51 f/s, eps 0.10
# 5996020: done 2876 games, mean reward 16.720, speed 115.59 f/s, eps 0.10
# 5997506: done 2877 games, mean reward 16.740, speed 117.03 f/s, eps 0.10
# 5998042: done 2878 games, mean reward 16.840, speed 113.09 f/s, eps 0.10
# 5999237: done 2879 games, mean reward 16.990, speed 115.63 f/s, eps 0.10

# %%
import os.path
cur_folder = os.getcwd()
model_folder = os.path.join(cur_folder,"models")
if not os.path.exists(model_folder):
    os.makedirs(model_folder)

model_file = os.path.join(model_folder, (tag + ".pt"))
torch.save(net.state_dict(), model_file)
